# %% [markdown]
# ### Stock News

# %% [raw]
# https://www.geeksforgeeks.org/web-scraping-financial-news-using-python/

# %%
urls = ["https://www.businesstoday.in/latest", "https://www.businesstoday.in/magazine/the-buzz","https://www.businesstoday.in/personal-finance/investment",
       "https://www.businesstoday.in/industry/banks"]

# %%
### Business Today:
urls = {
    "home": "https://www.businesstoday.in/",
    "home1": "https://www.businesstoday.in/interactive/",
    "home_upstart": "https://www.businesstoday.in/entrepreneurship",
    "home_g20": "https://www.businesstoday.in/g20-summit",
    "home_corporate": "https://www.businesstoday.in/latest/corporate",
    "magazine": "https://www.businesstoday.in/magazine",
    "editorial": "https://www.businesstoday.in/magazine/editors-note-0",
    "analysis" : "https://www.businesstoday.in/magazine/deep-dive",
    "interview" : "https://www.businesstoday.in/magazine/interview",
    "buzz": "https://www.businesstoday.in/magazine/the-buzz",
    "market_news": "https://www.businesstoday.in/bt-tv/market-today",
    "economic_analysis": "https://www.businesstoday.in/bt-tv/easynomics",
    "bt_explainer": "https://www.businesstoday.in/bt-tv/bt-explainer",
    "indices": "https://www.businesstoday.in/indices",
    "trending_stock": "https://www.businesstoday.in/markets/trending-stocks",
    "stock_in_news": "https://www.businesstoday.in/markets/company-stock",
    "stocks": "https://www.businesstoday.in/markets/stocks",
    "ipo": "https://www.businesstoday.in/markets/ipo-corner",
    "tax": "https://www.businesstoday.in/personal-finance/tax",
    "investment": "https://www.businesstoday.in/personal-finance/investment",
    "banking": "https://www.businesstoday.in/industry/banks",
    "auto": "https://www.businesstoday.in/auto",
    "commodities": "https://www.businesstoday.in/commodities",
    "real_estate": "https://www.businesstoday.in/personal-finance/real-estate",
    "it": "https://www.businesstoday.in/industry/it",
    "energy": "https://www.businesstoday.in/industry/energy",
    "pharma": "https://www.businesstoday.in/industry/pharma",
    "telecom": "https://www.businesstoday.in/industry/telecom",
  
    
}

# %%
from bs4 import BeautifulSoup as BS
import requests as req
 
url = "https://www.businesstoday.in/industry/banks"
 
webpage = req.get(url)
trav = BS(webpage.content, "html.parser")
M = 1
for link in trav.find_all('a'):
   
    # PASTE THE CLASS TYPE THAT WE GET
    # FROM THE ABOVE CODE IN THIS AND
    # SET THE LIMIT GREATER THAN 35
    if(str(type(link.string)) == "<class 'bs4.element.NavigableString'>"
       and len(link.string) > 35):
 
        print(str(M)+".", link.string)
        M += 1
# Out:
# 1. 'All movie villains were businessmen': IDFC First Bank's V Vaidyanathan on change in mindset for entrepreneurs in India
# 2.  BT500: 'Tragic to see rural India is most under-financed,' says IDFC First Bank MD & CEO V Vaidyanathan
# 3.  Ten PSBs transfer Rs 11,617 crore of bad loans to NARCL: MoS Finance in RS
# 4.  Indian banks want all Saturdays off, FinMin confirms in Parliament Winter session
# 5.  A little more than half of loans written off by SCBs are of large industries and services firms
# 6.
#                            Wall Street tumbles to sharply lower close as abrupt sell-off snaps rally
#
# 7.
#                            SEBI approves appointment of ex-IAS Pramod Agrawal as BSE Chairman
#
# 8.
#                            Passive funds tracking Nifty indices see 53% CAGR growth in assets in 10 years; AUM stands at $70 billion
#
# 9.
#                            Stay cautious! This Buffett indicator signals potential overvaluation on D-Street
#
# ...

# %%
from bs4 import BeautifulSoup as BS
import requests as req
 
url = "https://www.businesstoday.in/magazine/the-buzz"
 
webpage = req.get(url)
trav = BS(webpage.content, "html.parser")
M = 1
for link in trav.find_all('a'):
   
    # PASTE THE CLASS TYPE THAT WE GET
    # FROM THE ABOVE CODE IN THIS AND
    # SET THE LIMIT GREATER THAN 35
    if(str(type(link.string)) == "<class 'bs4.element.NavigableString'>"
       and len(link.string) > 35):
 
        print(str(M)+".", link.string)
        M += 1
# Out:
# 1. Bollywood finally sees a rebound in 2023 after two dud years
# 2. Aster DM Hospitals eyes expansion in North India with war chest from sale of its GCC business
# 3. Cyclone Michaung: Chennai’s image as an industrial hub has taken a hit
# 4. RBI is treading a careful path as it looks to pre-empt misadventures
# 5. Byju Raveendran is doing whatever it takes to keep employee morale up
# 6. Festive season sales: Automakers and realtors had reasons to cheer, but some concerns still exist
# 7. With BJP pocketing three big states in the Hindi heartland, the markets are perfectly poised for a rally
# 8. As India wraps up its G20 presidency, it is over to Brazil now
# 9. Q2 GDP: Despite higher-than-anticipated growth, concerns still abound
# 10. Gautam Singhania-Nawaz Modi feud: Uncertainty still abounds for Raymond's investors
# 11. WeWork bankruptcy: Why the US company's Indian arm is unfazed by the insolvency
# ...

# %%
trav
# Out:
# <!DOCTYPE html>
# ...

# %%
from bs4 import BeautifulSoup as BS
import requests as req
 
url = "https://www.businesstoday.in/magazine/the-buzz"

response = req.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BS(response.text, 'html.parser')

    # Find all the <a> elements with titles
#     anchor_tags = soup.find_all('a', {'title': True})
#     for anchor_tag in anchor_tags:
        
#         if(str(type(anchor_tag.string)) == "<class 'bs4.element.NavigableString'>"
#            and len(anchor_tag.string) > 35):
#             print(anchor_tag.string)
            
#         if(str(type(anchor_tag.find_next('p').string)) == "<class 'bs4.element.NavigableString'>"
#            and len(anchor_tag.find_next('p').string) > 35):
#             print(anchor_tag.find_next('p').string)        
        
    anchor_tags = soup.find_all('a', {'title': True})
    for anchor_tag in anchor_tags:


        if(str(type(anchor_tag.find_next('p').string)) == "<class 'bs4.element.NavigableString'>"
           and len(anchor_tag.find_next('p').string) > 35):
            print(anchor_tag.find_next('p').string)          
        
        
#         print(str(type(anchor_tag.find_next('p').string) ))
#         print(  len(anchor_tag.get_text()) )
#                   , len(anchor_tag.get_text())) )
#         heading = anchor_tag.get_text()
#         summary = anchor_tag.find_next('p').get_text()  # Assuming summaries are in <p> tags following the <a> tags
       
#         if len(summary) > 35:
        
# #             print("Heading:", heading)
#             print("Summary:", summary)
#         print("\n")
# Out:
# Bollywood is expected to end 2023 on a high with hits like Animal, after a relatively quiet period of almost two years
# Bollywood is expected to end 2023 on a high with hits like Animal, after a relatively quiet period of almost two years
# After selling its Gulf business, Aster DM Healthcare is doubling down on India, and is looking to expand in the North
# After selling its Gulf business, Aster DM Healthcare is doubling down on India, and is looking to expand in the North
# Chennai has suffered severe losses because of Cyclone Michaung, denting its image as an industrial hub
# Chennai has suffered severe losses because of Cyclone Michaung, denting its image as an industrial hub
# With the RBI calling for comprehensive regulations to govern connected-party lending, it wants to pre-empt any misadventure in the financial sector
# With the RBI calling for comprehensive regulations to govern connected-party lending, it wants to pre-empt any misadventure in the financial sector
# ...

# %%
anchor_tags
# Out:
# [<a aria-label="Business Today" class="gbl_nav_lnk" href="https://www.businesstoday.in" rel="noopener" target="_self" title="Business Today">Business Today</a>,
#  <a aria-label="BT Bazaar" class="gbl_nav_lnk" href="https://bazaar.businesstoday.in/" rel="noopener" target="_blank" title="BT Bazaar">BT Bazaar</a>,
#  <a aria-label="India Today" class="gbl_nav_lnk" href="https://www.indiatoday.in/" rel="noopener" target="_blank" title="India Today">India Today</a>,
#  <a aria-label="Northeast" class="gbl_nav_lnk" href="https://www.indiatodayne.in/" rel="noopener" target="_blank" title="Northeast">Northeast</a>,
#  <a aria-label="Web3Cafe" class="gbl_nav_lnk" href="https://www.web3cafe.in/" rel="noopener" target="_blank" title="Web3Cafe">Web3Cafe</a>,
#  <a aria-label="DailyO" class="gbl_nav_lnk" href="https://www.dailyo.in/" rel="noopener" target="_blank" title="DailyO">DailyO</a>,
# ...

# %%
from bs4 import BeautifulSoup as BS
import requests as req

url = "https://www.businesstoday.in/magazine/the-buzz"

response = req.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BS(response.text, 'html.parser')

    # Create a set to store extracted URLs
    extracted_urls = set()

    # Find all the <a> elements with titles
    anchor_tags = soup.find_all('a', {'title': True})

    for anchor_tag in anchor_tags:
        # Get the URL from the 'href' attribute
        link = anchor_tag.get('href')
        
        # Check if the URL is already in the set to avoid duplicates
        if link not in extracted_urls:
            extracted_urls.add(link)
            
            # Check if the summary text is present and has a length greater than 35
            summary = anchor_tag.find_next('p')
            if summary and len(summary.get_text()) > 35:
                print(summary.get_text())
                print("\n")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Bollywood is expected to end 2023 on a high with hits like Animal, after a relatively quiet period of almost two years
#
#
# After selling its Gulf business, Aster DM Healthcare is doubling down on India, and is looking to expand in the North
#
#
# Chennai has suffered severe losses because of Cyclone Michaung, denting its image as an industrial hub
#
#
# With the RBI calling for comprehensive regulations to govern connected-party lending, it wants to pre-empt any misadventure in the financial sector
#
#
# Byju Raveendran’s decision to pledge personal assets to meet salary obligations at his firm is being seen by some as proof of his commitment, but others are worried
#
#
# The festive season was bright for automakers and realtors, but sales in certain consumer goods segments remained flat
#
#
# The BJP’s victory in state elections is a perfect trigger for a rally, say market participants
#
#
# ...

# %%
from bs4 import BeautifulSoup as BS
import requests as req

url = "https://www.businesstoday.in/magazine/the-buzz"

response = req.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BS(response.text, 'html.parser')

    # Create a set to store extracted URLs
    extracted_urls = set()

    # Find all the <a> elements with titles
    anchor_tags = soup.find_all('a', {'title': True})

    for anchor_tag in anchor_tags:
        # Get the URL from the 'href' attribute
        link = anchor_tag.get('href')
        
        # Check if the URL is already in the set to avoid duplicates
        if link not in extracted_urls:
            extracted_urls.add(link)
            
            # Check if the summary text is present and has a length greater than 35
            summary = anchor_tag.find_next('p')
            
            # Exclude summaries containing the copyright notice
            if summary and len(summary.get_text()) > 35 and "Copyright©2023 Living Media India Limited. For reprint rights: Syndications Today" not in summary.get_text():
                print(summary.get_text())
                print("\n")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Bollywood is expected to end 2023 on a high with hits like Animal, after a relatively quiet period of almost two years
#
#
# After selling its Gulf business, Aster DM Healthcare is doubling down on India, and is looking to expand in the North
#
#
# Chennai has suffered severe losses because of Cyclone Michaung, denting its image as an industrial hub
#
#
# With the RBI calling for comprehensive regulations to govern connected-party lending, it wants to pre-empt any misadventure in the financial sector
#
#
# Byju Raveendran’s decision to pledge personal assets to meet salary obligations at his firm is being seen by some as proof of his commitment, but others are worried
#
#
# The festive season was bright for automakers and realtors, but sales in certain consumer goods segments remained flat
#
#
# The BJP’s victory in state elections is a perfect trigger for a rally, say market participants
#
#
# ...

# %%
from bs4 import BeautifulSoup as BS
import requests as req

url = "https://www.businesstoday.in/magazine/the-buzz"

response = req.get(url)


# Parse the HTML content using BeautifulSoup
soup = BS(response.text, 'html.parser')

# Find all the <div> elements with class "widget-listing"
listing_divs = soup.find_all('div', class_='widget-listing')

for div in listing_divs:
    # Extract the date updated
    date_updated = div.find('span').text.strip()
    
    # Extract the news heading
    heading = div.find('h2').find('a').text.strip()
    
    # Extract the news summary
    summary = div.find('p').text.strip()
    
    print("Date Updated:", date_updated)
    print("News Heading:", heading)
    print("News Summary:", summary)
    print("\n")
# Out:
# Date Updated: Updated : Dec 20, 2023
# News Heading: Bollywood finally sees a rebound in 2023 after two dud years
# News Summary: Bollywood is expected to end 2023 on a high with hits like Animal, after a relatively quiet period of almost two years
#
#
# Date Updated: Updated : Dec 20, 2023
# News Heading: Aster DM Hospitals eyes expansion in North India with war chest from sale of its GCC business
# News Summary: After selling its Gulf business, Aster DM Healthcare is doubling down on India, and is looking to expand in the North
#
#
# Date Updated: Updated : Dec 20, 2023
# News Heading: Cyclone Michaung: Chennai’s image as an industrial hub has taken a hit
# News Summary: Chennai has suffered severe losses because of Cyclone Michaung, denting its image as an industrial hub
#
#
# Date Updated: Updated : Dec 20, 2023
# News Heading: RBI is treading a careful path as it looks to pre-empt misadventures
# ...

# %%
listing_divs
# Out:
# []

# %% [markdown]
# ### Financial Express

# %%
url = {
    "head":"https://www.financialexpress.com/",
    "india_news":"https://www.financialexpress.com/india-news/",
    "industry": "https://www.financialexpress.com/business/industry/",
    "market": "https://www.financialexpress.com/market/",
    "healthcare":"https://www.financialexpress.com/healthcare/",
    "money":"https://www.financialexpress.com/money/",
    "auto":"https://www.financialexpress.com/auto/",
    "digital":"https://www.financialexpress.com/business/digital-transformation/",
    "ai":"https://www.financialexpress.com/about/artificial-intelligence/",
    "business_tech":"https://www.financialexpress.com/about/business-technology/",
    "cloud":"https://www.financialexpress.com/about/cloud-verse/",
    "information":"https://www.financialexpress.com/about/cloud-verse/",
    "sme":"https://www.financialexpress.com/business/sme/",
    "web_story":"https://www.financialexpress.com/web-stories/",

    
}

# %% [markdown]
# ### Bloomberg

# %%
below list not complete
url = {
    "asia": "https://www.bloomberg.com/asia",
    "market": "https://www.bloomberg.com/markets",
    "economics": "https://www.bloomberg.com/economics",
    "industry": "https://www.bloomberg.com/industries",
    "tech": "https://www.bloomberg.com/technology",
    "ai": "https://www.bloomberg.com/ai",
    "politics": "https://www.bloomberg.com/politics",
    "wealth": "https://www.bloomberg.com/wealth",
    "pursuit": "https://www.bloomberg.com/pursuits",
    "opinion": "https://www.bloomberg.com/opinion",
    "buss_week":"https://www.bloomberg.com/businessweek",
    "":"https://www.bloomberg.com/equality",
    "equality":"https://www.bloomberg.com/equality",
    "green":"https://www.bloomberg.com/green",
    "":"",
    "":"",
    "":"",

}

# %% [markdown]
# ### CNBC

# %%
below list not complete
url = {
    
"head":"https://www.cnbc.com/world/?region=world",
"buss":"https://www.cnbc.com/business/",
    
"":"",
"":"",
"":"",
"":"",
"":"",
"":"",

}

# %% [markdown]
# ### Money Control

# %% [markdown]
# https://www.moneycontrol.com/news/business/

# %%
url = {
    "stockmarket":"https://www.moneycontrol.com/stocksmarketsindia/",
    "volume":"https://www.moneycontrol.com/stocks/marketstats/nse_vshockers/index.php",
    "news":"https://www.moneycontrol.com/news/",
    "buss_news1":"https://www.moneycontrol.com/news/business/",
    "buss_news2":"https://www.moneycontrol.com/news/business/page-2/",
    "buss_news3":"https://www.moneycontrol.com/news/business/page-3/",
    "economy_news1":"https://www.moneycontrol.com/news/business/economy/",
    "economy_news2":"https://www.moneycontrol.com/news/business/economy/page-2/",
    "economy_news3":"https://www.moneycontrol.com/news/business/economy/page-3/",
    "comapny_news1":"https://www.moneycontrol.com/news/tags/companies.html",
    "comapny_news2":"https://www.moneycontrol.com/news/tags/companies.html/page-2/",
    "comapny_news3":"https://www.moneycontrol.com/news/tags/companies.html/page-3/",
    "mutual_fund_news1":"https://www.moneycontrol.com/news/business/mutual-funds/",
    "mutual_fund_news2":"https://www.moneycontrol.com/news/business/mutual-funds/page-2/",
    "mutual_fund_news3":"https://www.moneycontrol.com/news/business/mutual-funds/page-3/",
    "persona_finance1":"https://www.moneycontrol.com/news/business/personal-finance/",
    "startup_news1":"https://www.moneycontrol.com/news/business/startups/",
    "startup_news2":"https://www.moneycontrol.com/news/business/startups/page-2/",
    "startup_news3":"https://www.moneycontrol.com/news/business/startups/page-3/",
    "india_news1":"https://www.moneycontrol.com/news/india/",
    "india_news2":"https://www.moneycontrol.com/news/india/page-2/",
    "india_news3":"https://www.moneycontrol.com/news/india/page-3/",
    "world_news1":"https://www.moneycontrol.com/news/world/",
    "world_news2":"https://www.moneycontrol.com/news/world/page-2/",
    "world_news3":"https://www.moneycontrol.com/news/world/page-3/",
    "stock_news1":"https://www.moneycontrol.com/news/business/markets/",
    "stock_news2":"https://www.moneycontrol.com/news/business/markets/page-2/",
    "stock_news3":"https://www.moneycontrol.com/news/business/markets/page-3/",
    "technical_analysis_news1":"https://www.moneycontrol.com/news/tags/technical-analysis.html",
    "technical_analysis_news2":"https://www.moneycontrol.com/news/tags/technical-analysis.html/page-2/",
    "technical_analysis_news3":"https://www.moneycontrol.com/news/tags/technical-analysis.html/page-3/",
    "commodity_news1":"https://www.moneycontrol.com/news/business/commodity/",
    "commodity_news2":"https://www.moneycontrol.com/news/business/commodity/page-2/",
    "commodity_news3":"https://www.moneycontrol.com/news/business/commodity/page-3/",
    "mclearn_moneycontrol1":"https://www.moneycontrol.com/news/tags/mc-learn.html",
    "politics":"https://www.moneycontrol.com/news/politics/",
    "lifestyle":"https://www.moneycontrol.com/news/trends/lifestyle/",

}

# %%
from bs4 import BeautifulSoup as BS
import requests as req
import pandas as pd

def dataframe_news(url):
#     print(url)
#     url = "https://www.moneycontrol.com/news/business/economy/"

    response = req.get(url)


    # Parse the HTML content using BeautifulSoup
    soup = BS(response.text, 'html.parser')

    # Find all the <div> elements with class "widget-listing"
    listing_divs = soup.find_all('li', class_='clearfix')

    date = []
    heading = []
    text = []

    for div in listing_divs:
    #     print(div)

        date.append( div.find('span').text.strip() )

        # Extract the heading
        heading.append(div.find('h2').find('a').text.strip() )

        # Extract the text
        text.append(div.find('p').text.strip() )

    df = pd.DataFrame(
        {'date': date,
         'heading': heading,
         'text': text
        })
    return df

# %%
for i in url:
    print(i)
# Out:
# stockmarket
# volume
# news
# buss_news1
# buss_news2
# buss_news3
# economy_news1
# economy_news2
# economy_news3
# comapny_news1
# comapny_news2
# comapny_news3
# mutual_fund_news1
# mutual_fund_news2
# mutual_fund_news3
# persona_finance1
# startup_news1
# startup_news2
# startup_news3
# india_news1
# india_news2
# india_news3
# world_news1
# world_news2
# world_news3
# stock_news1
# stock_news2
# stock_news3
# technical_analysis_news1
# technical_analysis_news2
# technical_analysis_news3
# commodity_news1
# commodity_news2
# commodity_news3
# mclearn_moneycontrol1
# politics
# lifestyle

# %%
url["stockmarket"]
# Out:
# 'https://www.moneycontrol.com/stocksmarketsindia/'

# %%
final_news = pd.DataFrame()
missing = []
for i in url:
    try:
        df = dataframe_news(url[i])
        df["SourceTag"] = i
        final_news = pd.concat([final_news,df])
        print(url[i])

    except:
        missing.append(url[i])
# Out:
# https://www.moneycontrol.com/news/business/
# https://www.moneycontrol.com/news/business/page-2/
# https://www.moneycontrol.com/news/business/page-3/
# https://www.moneycontrol.com/news/business/economy/
# https://www.moneycontrol.com/news/business/economy/page-2/
# https://www.moneycontrol.com/news/business/economy/page-3/
# https://www.moneycontrol.com/news/tags/companies.html
# https://www.moneycontrol.com/news/tags/companies.html/page-2/
# https://www.moneycontrol.com/news/tags/companies.html/page-3/
# https://www.moneycontrol.com/news/business/mutual-funds/
# https://www.moneycontrol.com/news/business/mutual-funds/page-2/
# https://www.moneycontrol.com/news/business/mutual-funds/page-3/
# https://www.moneycontrol.com/news/business/personal-finance/
# https://www.moneycontrol.com/news/business/startups/
# https://www.moneycontrol.com/news/business/startups/page-2/
# https://www.moneycontrol.com/news/business/startups/page-3/
# https://www.moneycontrol.com/news/india/
# ...

# %%
missing
# Out:
# ['https://www.moneycontrol.com/stocksmarketsindia/',
#  'https://www.moneycontrol.com/stocks/marketstats/nse_vshockers/index.php',
#  'https://www.moneycontrol.com/news/',
#  'https://www.moneycontrol.com/news/business/commodity/',
#  'https://www.moneycontrol.com/news/business/commodity/page-3/']

# %%
final_news.to_csv("final_news_moneycontrol.csv")

# %%
pwd
# Out:
# 'C:\\Users\\Asehgal\\practice_notebook\\AlgoTrading'

# %% [markdown]
# ### Name Entity Recognition using LLM

# %% [raw]
# Model = "Llama2" or "BERT"

# %% [raw]
# BERT Source:
# 1. https://towardsdatascience.com/custom-named-entity-recognition-with-bert-cf1fd4510804
# 2. https://www.freecodecamp.org/news/getting-started-with-ner-models-using-huggingface/
# 3. https://huggingface.co/dslim/bert-base-NER
# 4. https://www.freecodecamp.org/news/getting-started-with-ner-models-using-huggingface/

# %%
# !pip install tokenizers
# !pip install transformers
# !pip install torch

# %% [markdown]
# #### BERT

# %% [raw]
# https://colab.research.google.com/drive/1GG95b_GgMbzEmU6QN1LJzajPB__04F6F?authuser=0#scrollTo=PsVR_D_tF-Am

# %%
import torch
from transformers import BertTokenizer, BertForTokenClassification

# Load the pre-trained BERT model and tokenizer
model_name = "bert-base-uncased"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForTokenClassification.from_pretrained(model_name)
# Out:
# ...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Input In [2], in <cell line: 7>()
#       5 model_name = "bert-base-uncased"
#       6 tokenizer = BertTokenizer.from_pretrained(model_name)
# ----> 7 model = BertForTokenClassification.from_pretrained(model_name)
#
# File ~\anaconda3\lib\site-packages\transformers\modeling_utils.py:2785, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2770 try:
#    2771     # Load from URL or cache if already cached
#    2772     cached_file_kwargs = {
#    2773         "cache_dir": cache_dir,
#    2774         "force_download": force_download,
#    (...)
#    2783         "_commit_hash": commit_hash,
#    2784     }
# ...

# %%
from transformers import BertForTokenClassification, BertTokenizer, pipeline
model_name = "dbmdz/bert-large-cased-finetuned-conll03-english"
tokenizer = BertTokenizer.from_pretrained(model_name)
model = BertForTokenClassification.from_pretrained(model_name)

nlp_ner = pipeline("ner", model=model, tokenizer=tokenizer)

text = "Barack Obama was born in Hawaii."
entities = nlp_ner(text)
print(entities)

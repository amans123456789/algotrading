# %%
ticker_alternate = ['abbottindia','bandhanbank','canfinhomes','cityunionbank','icicilombardgeneralinsurancecompany','irctc-indianrailwaycateringtourismcorp',
 'mahanagargas', 'nestleindia','pageindustries', 'sbicardspaymentservices', 'sbilifeinsurancecompany', 'ausmallfinancebank','abbindia','abbottindia','canfinhomes'
   ,'hdfcassetmanagementcompany','icicilombardgeneralinsurancecompany'  , 'irctc-indianrailwaycateringtourismcorp',
                   'mahanagargas','nestleindia','pageindustries','sbicardspaymentservices','sbilifeinsurancecompany']



tickers = ["abbindia", "acc","ausmallfinancebank","aartiindustries","abbottindia",
          "adanienterprises","adaniportsspecialeconomiczone","adityabirlacapital",
          "adityabirlafashionretail","alkemlaboratories", "ambujacements", "apollohospitalsenterprises", "apollotyres",
          "ashokleyland","asianpaints","astrallimited","atul","aurobindopharma","axisbank",
          "bajajauto","bajajfinance","bajajfinserv","balkrishnaindustries","balrampurchinimills",
          "bandhanbank","bankbaroda","bataindia","bergerpaintsindia","bharatelectronics","bharatforge",
          "bharatheavyelectricals","bharatpetroleumcorporation","bhartiairtel","biocon","birlasoft",
          "bosch","britanniaindustries","canfinhomes","canarabank","chambalfertiliserschemicals","cholamandalaminvestmentfinancecompany",
          "cipla","cityunionbank","coalindia","coforgelimited" ,"colgatepalmoliveindia","containercorporationindia","coromandelinternational",
          "cromptongreavesconsumerelectrical","cumminsindia","dlf","daburindia","dalmiabharat","deepaknitrite","deltacorp", "divislaboratories",
          "dixontechnologies","drlalpathlabs","drreddyslaboratories","eichermotors","escortskubota","exideindustries","federalbank","gailindia",
          "gmrairportsinfrastructure","glenmarkpharma","godrejconsumerproducts","godrejproperties","granulesindia","grasimindustries","gujaratgas",
          "gujaratnarmadavalleyfertchem","hcltechnologies","hdfcassetmanagementcompany","hdfcbank","hdfclifeinsurancecompany","havellsindia","heromotocorp",
          "hindalcoindustries","hindustanaeronauticsltd","hindustancopper","hindustanpetroleumcorporation","hindustanunilever","icicibank","icicilombardgeneralinsurancecompany",
          "iciciprudentiallifeinsurancecompany","idfcfirstbank","idfc","itc","indiacements", "indiabullshousingfinance", "indiamartintermesh","indianenergyexchange","indianhotelscompany",
          "indianoilcorporation","irctc-indianrailwaycateringtourismcorp","indraprasthagas","industowers","indusindbank","infoedgeindia", "infosys","interglobeaviation","ipcalaboratories",
          "jkcement","jswsteel","jindalsteelpower","jubilantfoodworks", "kotakmahindrabank","ltfinanceholdings","lttechnologyservices","lichousingfinance","ltimindtree","larsentoubro",
          "lauruslabs", "lupin","mrf","mahanagargas","mahindramahindrafinancialservices","mahindramahindra","manappuramfinance","marico","marutisuzukiindia","maxfinancialservices",
          "metropolishealthcare", "mphasis","multicommodityexchangeindia","muthootfinance","nmdc","ntpc","nationalaluminiumcompany","navinfluorineinternational",
          "nestleindia","oberoirealty","oilnaturalgascorporation","oraclefinancialservicessoftware","piindustries","pvrinox","pageindustries","persistentsystems",
          "petronetlng","pidiliteindustries","piramalenterprises","polycabindia","powerfinancecorporation","powergridcorporationindia","punjabnationalbank","rblbank",
          "rec","relianceindustries","sbicardspaymentservices","sbilifeinsurancecompany","srf","samvardhanamothersoninternational","shreecements","shriramfinance","siemens","statebankindia",
          "steelauthorityindia","sunpharmaceuticalindustries","suntvnetwork","syngeneinternational","tvsmotorcompany","tatachemicals","tatacommunications","tataconsultancyservices","tataconsumerproducts",
          "tatamotors", "thetatapowercompany","tatasteel","techmahindra","theramcocements","titancompany","torrentpharmaceuticals","trent", "upl","ultratechcement","unitedbreweries","unitedspirits",
          "vedanta","vodafoneidealimited","voltas","wipro","zeeentertainmententerprises","zyduslifesciences"]

ti = ["ABB", "ACC06","ASF02","AI45","AI51","AE13","MPS","ABC9","PFR","AL05","AC18","AHE" ,"AT14",
     "AL","AP31","APT02","A06","AP","AB16","BA10","BAF","BF04","BI03","BCM","BB09","BOB","BI01",
     "BPI02","BE03","BF03","BHE","BPC","BA08","BL03","KPI02","B05","BI","CFH","CB06","CFC","CDB",
     "C","CUB","CI11","NII02","CPI","CCI","CI45","CGC01","CI02","D04","DI","OCL","DN","DC11","DL03",
      "DT07","DLP01","DRL","EM", "E","EI","FB","GAI","GI27","GP08","GCP","GP11","GI25","GI01","GGC","GNV",
      "HCL02","HAM02","HDF01","HSL01","HI01","HHM","HI","HAL","HC07","HPC","HU","ICI02","ILG","IPL01","IDF01",
      "IDF","ITC","IC", "IHF01", "II12","IEE","IHC","IOC","IRC","IG04","BI14","IIB","IEI01","IT", "IA04","IL",
      "JKC03","JSW01","JSP", "JF04","KMB","LFH","LTS","LIC","LI12","LT","LL05","L","MRF","MG02","MMF04","MM","MGF01",
      "M13","MS24","MI","MH06","MB02","MCE","MF10","NMD02","NTP","NAC","NFI","NI","OR","ONG","OFS01","PII","PVR","PI35","PS15",
      "PLN","PI11","PH05","PI44","PFC02","PGC","PNB05","RB03","REC02","RI","SCP02","SLI03","SRF","MSS01","SC12","STF","S","SBI",
      "SAI","SPI","STN01","SI10","TVS","TC","TC17","TCS","TT","TM03","TPC","TIS","TM4","MC","TI01","TP06","T04","UP04","UTC01","UB02",
      "US","SG","IC8","V","W","ZEE","CHC"
     ]

sector = {}


sector["abbindia"] = "infrastructure-general"
sector["acc"] = "cement-major"
sector["ausmallfinancebank"] = "banks-private-sector"
sector["aartiindustries"] = "chemicals"
sector["abbottindia"] = "pharmaceuticals"
sector["adanienterprises"] = "trading"
sector["adaniportsspecialeconomiczone"] = "infrastructure-general"
sector["adityabirlacapital"] = "finance-investments"
sector["adityabirlafashionretail"] = "retail"
sector["alkemlaboratories"] = "pharmaceuticals"

sector["ambujacements"] = "cement-major"
sector["apollohospitalsenterprises"] = "hospitalsmedical-services"
sector["apollotyres"] = "tyres"
sector["ashokleyland"] = "auto-lcvshcvs"
sector["asianpaints"] = "paintsvarnishes"
sector["astrallimited"] = "plastics"
sector["atul"] = "chemicals"
sector["aurobindopharma"] = "pharmaceuticals"
sector["axisbank"] = "banks-private-sector"
sector["bajajauto"] = "auto-23-wheelers"


sector["bajajfinance"] = "finance-nbfc"
sector["bajajfinserv"] = "finance-nbfc"
sector["balkrishnaindustries"] = "tyres"
sector["balrampurchinimills"] = "sugar"
sector["bandhanbank"] = "banks-private-sector"
sector["bankbaroda"] = "banks-public-sector"
sector["bataindia"] = "leather-products"
sector["bergerpaintsindia"] = "paintsvarnishes"
sector["bharatelectronics"] ="aerospacedefence"
sector["bharatforge"] ="castingsforgings"
sector["bharatheavyelectricals"] = "infrastructure-general"
sector["bharatpetroleumcorporation"] = "refineries"
sector["bhartiairtel"] = "telecommunications-service"
sector["biocon"] = "pharmaceuticals"
sector["birlasoft"] = "computers-software-mediumsmall"
sector["bosch"] = "auto-ancillaries"
sector["britanniaindustries"] = "food-processing"
sector["canfinhomes"] = "finance-housing"
sector["canarabank"] = "banks-public-sector"

sector["chambalfertiliserschemicals"] = "fertilisers"
sector["cholamandalaminvestmentfinancecompany"] = "finance-nbfc"
sector["cipla"] = "pharmaceuticals"
sector["cityunionbank"] = "banks-private-sector"
sector["coalindia"] = "miningminerals"
sector["coforgelimited"] = "computers-software"
sector["colgatepalmoliveindia"] = "personal-care"
sector["containercorporationindia"] = "transportlogistics"
sector["coromandelinternational"] = "fertilisers"
sector["cromptongreavesconsumerelectrical"] = "electricals"
sector["cumminsindia"] = "engines"
sector["dlf"] = "constructioncontracting-real-estate"
sector["daburindia"] = "personal-care"
sector["dalmiabharat"] = "cement-major"
sector["deepaknitrite"] = "chemicals"
sector["deltacorp"] = "constructioncontracting-real-estate"
sector["divislaboratories"] = "pharmaceuticals"
sector["dixontechnologies"] = "electricals"
sector["drlalpathlabs"] = "pharmaceuticals"
sector["drreddyslaboratories"] = "pharmaceuticals"
sector["eichermotors"] = "auto-lcvshcvs"
sector["escortskubota"] = "automobile-tractors"
sector["exideindustries"] = "auto-ancillaries"

sector["federalbank"] = "banks-private-sector"
sector["gailindia"] = "oil-drillingexploration"
sector["gmrairportsinfrastructure"] = "transport-infrastructure"
sector["glenmarkpharma"] = "pharmaceuticals"
sector["godrejconsumerproducts"] = "personal-care"
sector["godrejproperties"] = "constructioncontracting-real-estate"
sector["granulesindia"] = "pharmaceuticals"
sector["grasimindustries"] = "diversified"
sector["gujaratgas"] = "oil-drillingexploration"
sector["gujaratnarmadavalleyfertchem"] = "gujaratnarmadavalleyfertchem"
sector["hcltechnologies"] = "computers-software"
sector["hdfcassetmanagementcompany"] = "finance-investments"
sector["hdfcbank"] = "banks-private-sector"
sector["hdfclifeinsurancecompany"] = "lifehealth-insurance"
sector["havellsindia"] = "electric-equipment"
sector["heromotocorp"] = "auto-23-wheelers"
sector["hindalcoindustries"] = "ironsteel"
sector["hindustanaeronauticsltd"] = "diversified"
sector["hindustancopper"] = "metals-non-ferrous"
sector["hindustanpetroleumcorporation"] = "refineries"
sector["hindustanunilever"] = "personal-care"
sector["icicibank"] = "banks-private-sector"
sector["icicilombardgeneralinsurancecompany"] = "multiline-insurancebrokers"
sector["iciciprudentiallifeinsurancecompany"] = "finance-general"
sector["idfcfirstbank"] = "banks-private-sector"
sector["idfc"] = "finance-housing"
sector["itc"] = "diversified"
sector["indiacements"] = "cement-major"
sector["indiabullshousingfinance"] = "finance-housing"
sector["indiacements"] = "cement-major"
sector["indiamartintermesh"] = "miscellaneous"
sector["indianenergyexchange"] = "diversified"
sector["indianhotelscompany"] = "hotels"
sector["indianoilcorporation"] = "refineries"
sector["irctc-indianrailwaycateringtourismcorp"] = "miscellaneous"

sector["indraprasthagas"] = "oil-drillingexploration"
sector["industowers"] = "telecommunications-equipment"
sector["indusindbank"] = "banks-private-sector"
sector["infoedgeindia"] = "miscellaneous"
sector["infosys"] = "computers-software"
sector["interglobeaviation"] = "transportlogistics"
sector["ipcalaboratories"] = "pharmaceuticals"
sector["jkcement"] = "cement-major"
sector["jswsteel"] = "steel-large"
sector["jindalsteelpower"] = "steel-sponge-iron"
sector["jubilantfoodworks"] = "miscellaneous"
sector["kotakmahindrabank"] = "banks-private-sector"
sector["ltfinanceholdings"] = "finance-investments"
sector["lttechnologyservices"] = "engineering"
sector["lichousingfinance"] = "finance-housing"
sector["ltimindtree"] = "computers-software"
sector["larsentoubro"] = "infrastructure-general"
sector["lauruslabs"] = "pharmaceuticals"
sector["lupin"] = "pharmaceuticals"
sector["mrf"] = "tyres"
sector["mahanagargas"] = "refineries"
sector["mahindramahindrafinancialservices"] = "finance-nbfc"
sector["mahindramahindra"] = "auto-carsjeeps"
sector["manappuramfinance"] = "finance-leasinghire-purchase"
sector["marico"] = "personal-care"
sector["marutisuzukiindia"] = "auto-carsjeeps"
sector["maxfinancialservices"] = "finance-investments"
sector["metropolishealthcare"] = "hospitalsmedical-services"
sector["mphasis"] = "computers-software"
sector["multicommodityexchangeindia"] = "miscellaneous"
sector["muthootfinance"] = "finance-investments"
sector["nmdc"] = "miningminerals"
sector["ntpc"] = "power-generationdistribution"

sector["nationalaluminiumcompany"] = "aluminium"
sector["navinfluorineinternational"] = "chemicals"
sector["nestleindia"] = "food-processing"
sector["oberoirealty"] = "constructioncontracting-real-estate"
sector["oilnaturalgascorporation"] = "oil-drillingexploration"
sector["oraclefinancialservicessoftware"] = "computers-software"
sector["piindustries"] = "pesticidesagro-chemicals"
sector["pvrinox"] = "mediaentertainment"
sector["pageindustries"] = "textiles-readymade-apparels"
sector["persistentsystems"] = "computers-software"
sector["petronetlng"] = "oil-drillingexploration"
sector["pidiliteindustries"] = "chemicals"
sector["piramalenterprises"] = "finance-nbfc"
sector["polycabindia"] = "cables-powerothers"
sector["powerfinancecorporation"] = "finance-term-lending-institutions"
sector["powergridcorporationindia"] = "power-generationdistribution"
sector["punjabnationalbank"] = "banks-public-sector"
sector["rblbank"] = "banks-private-sector"
sector["rec"] = "finance-term-lending-institutions"
sector["relianceindustries"] = "refineries"
sector["sbicardspaymentservices"] = "finance-term-lending"
sector["sbilifeinsurancecompany"] = "lifehealth-insurance"
sector["srf"] = "diversified"
sector["samvardhanamothersoninternational"] = "auto-ancillaries-auto-truckmotorcycle-parts"
sector["shreecements"] = "cement-major"
sector["shriramfinance"] = "finance-leasinghire-purchase"
sector["siemens"] = "infrastructure-general"
sector["statebankindia"] = "banks-public-sector"
sector["steelauthorityindia"] = "steel-large"
sector["sunpharmaceuticalindustries"] = "pharmaceuticals"
sector["suntvnetwork"] = "mediaentertainment"
sector["syngeneinternational"] = "miscellaneous"
sector["tvsmotorcompany"] = "auto-23-wheelers"
sector["tatachemicals"] = "chemicals"
sector["tatacommunications"] = "telecommunications-service"
sector["tataconsultancyservices"] = "computers-software"
sector["tataconsumerproducts"] = "plantations-teacoffee"
sector["tatamotors"] = "auto-lcvshcvs"
sector["thetatapowercompany"] = "power-generationdistribution"
sector["tatasteel"] = "ironsteel"
sector["techmahindra"] = "computers-software"
sector["theramcocements"] ="cement-major"
sector["titancompany"] = "miscellaneous"
sector["torrentpharmaceuticals"] = "pharmaceuticals"
sector["trent"] = "retail"
sector["upl"] = "chemicals"
sector["ultratechcement"] = "cement-major"
sector["unitedbreweries"] = "breweriesdistilleries"
sector["unitedspirits"] = "breweriesdistilleries"
sector["vedanta"] = "miningminerals"
sector["vodafoneidealimited"] = "telecommunications-service"
sector["voltas"] = "diversified"
sector["wipro"] = "computers-software"
sector["zeeentertainmententerprises"] = "mediaentertainment"
sector["zyduslifesciences"] = "pharmaceuticalsdrugs"

# %%
import pandas as pd
import requests

# %%
def cash_flow(ticker, ti):

    url = 'https://www.moneycontrol.com/financials/{}/consolidated-cash-flowVI/{}'.format(ticker,ti)
    print(url)
    df = pd.read_html(requests.post(url).text)[0]

    return df

def cash_flow_alternate(ticker, ti):

    url = 'https://www.moneycontrol.com/financials/{}/cash-flowVI/{}'.format(ticker,ti)
    print(url)
    df = pd.read_html(requests.post(url).text)[0]

    return df

def run_stock_performance(tickers):
    fin = []
    missing_inc = []
    for i in range(len(tickers)):
        try:
            if tickers[i] in ticker_alternate:

                df = pd.DataFrame()
                df = cash_flow_alternate(tickers[i], ti[i])
                df["Stock"] = tickers[i]
                fin.append(df)
            else:
                df = pd.DataFrame()
                df = cash_flow(tickers[i], ti[i])
                df["Stock"] = tickers[i]
                fin.append(df)
        except:
            missing_inc.append(tickers[i])

            
    for i in missing_inc:
        if tickers[i] in Stock_List.ticker_alternate:

            df = pd.DataFrame()
            df = cash_flow_alternate(tickers[i], Stock_List.ti[i])
            df["Stock"] = tickers[i]
            fin.append(df)
        else:
            df = pd.DataFrame()
            df = cash_flow(tickers[i], Stock_List.ti[i])
            df["Stock"] = tickers[i]
            fin.append(df)            


    cfs = pd.concat(fin)
    return cfs

# %%
missing_inc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [19], in <cell line: 1>()
# ----> 1 missing_inc
#
# NameError: name 'missing_inc' is not defined

# %%
res_cfs = run_stock_performance(tickers)
# Out:
# https://www.moneycontrol.com/financials/abbindia/cash-flowVI/ABB
# https://www.moneycontrol.com/financials/acc/consolidated-cash-flowVI/ACC06
# https://www.moneycontrol.com/financials/ausmallfinancebank/cash-flowVI/ASF02
# https://www.moneycontrol.com/financials/aartiindustries/consolidated-cash-flowVI/AI45
# https://www.moneycontrol.com/financials/abbottindia/cash-flowVI/AI51
# https://www.moneycontrol.com/financials/adanienterprises/consolidated-cash-flowVI/AE13
# https://www.moneycontrol.com/financials/adaniportsspecialeconomiczone/consolidated-cash-flowVI/MPS
# https://www.moneycontrol.com/financials/adityabirlacapital/consolidated-cash-flowVI/ABC9
# https://www.moneycontrol.com/financials/adityabirlafashionretail/consolidated-cash-flowVI/PFR
# https://www.moneycontrol.com/financials/alkemlaboratories/consolidated-cash-flowVI/AL05
# https://www.moneycontrol.com/financials/ambujacements/consolidated-cash-flowVI/AC18
# 4    442.44  -390.68   143.71 NaN           abbindia
# ..      ...      ...      ...  ..                ...
# 6     -4.20     7.90     0.00 NaN  zyduslifesciences
# 7   -107.90     0.00   261.30 NaN  zyduslifesciences
# 8    -90.50   398.90  -810.90 NaN  zyduslifesciences
# 9   1177.70   778.80  1589.70 NaN  zyduslifesciences
# 10  1087.20  1177.70   778.80 NaN  zyduslifesciences
#
# [2009 rows x 8 columns]

# %%
pd.read_csv("cash_flow.csv")
# Out:
#       Unnamed: 0                                                  0        1  \
# 0              0                Cash Flow of ABB India (in Rs. Cr.)   Dec 22
# 1              1                                                NaN  12 mths
# 2              2  Net Profit/Loss Before Extraordinary Items And...  1362.79
# 3              3             Net CashFlow From Operating Activities   741.94
# 4              4              Net Cash Used In Investing Activities  1826.22
# ...          ...                                                ...      ...
# 2004           6                    Foreign Exchange Gains / Losses     6.60
# 2005           7  Adjustments On Amalgamation Merger Demerger Ot...     0.00
# 2006           8           Net Inc/Dec In Cash And Cash Equivalents  -533.80
# 2007           9            Cash And Cash Equivalents Begin of Year  1106.90
# 2008          10              Cash And Cash Equivalents End Of Year   573.10
#
#              2        3        4        5   6              Stock
# 0       Dec 21   Dec 20   Dec 19   Dec 18 NaN           abbindia
# 1      12 mths  12 mths  12 mths  12 mths NaN           abbindia
# 2       707.19   304.37   444.00   794.24 NaN           abbindia
# 3       649.24   318.22   666.87   625.46 NaN           abbindia
# 4     -2007.87   442.44  -390.68   143.71 NaN           abbindia
# ...        ...      ...      ...      ...  ..                ...
# 2004      8.60    -4.20     7.90     0.00 NaN  zyduslifesciences
# 2005    -25.90  -107.90     0.00   261.30 NaN  zyduslifesciences
# 2006   2372.90   -90.50   398.90  -810.90 NaN  zyduslifesciences
# 2007   1087.20  1177.70   778.80  1589.70 NaN  zyduslifesciences
# 2008   3460.10  1087.20  1177.70   778.80 NaN  zyduslifesciences
#
# [2009 rows x 9 columns]

# %%
pd.read_csv("general_performance.csv").Stock.nunique()
# Out:
# 184

# %%
import pandas as pd
import requests

def inc_statement(ticker, ti):

    url = 'https://www.moneycontrol.com/financials/{}/results/consolidated-yearly/{}'.format(ticker,ti)
    print(url)
    df = pd.read_html(requests.post(url).text)[0]

    return df

def inc_statement_alternate(ticker, ti):

    url = 'https://www.moneycontrol.com/financials/{}/results/yearly/{}'.format(ticker,ti)
    print(url)
    df = pd.read_html(requests.post(url).text)[0]

    return df

def run_stock_performance(tickers):
    fin = []
    missing_inc = []
    for i in range(len(tickers)):
        try:
            if tickers[i] in ticker_alternate:

                df = pd.DataFrame()
                df = inc_statement_alternate(tickers[i], ti[i])
                df["Stock"] = tickers[i]
                fin.append(df)
            else:
                df = pd.DataFrame()
                df = inc_statement(tickers[i], ti[i])
                df["Stock"] = tickers[i]
                fin.append(df)
        except:
            missing_inc.append(i)

    for i in missing_inc:
        if tickers[i] in ticker_alternate:

            df = pd.DataFrame()
            df = inc_statement_alternate(tickers[i], ti[i])
            df["Stock"] = tickers[i]
            fin.append(df)
        else:
            df = pd.DataFrame()
            df = inc_statement(tickers[i], ti[i])
            df["Stock"] = tickers[i]
            fin.append(df)

    incs = pd.concat(fin)
    return incs

# %%
res_ics = run_stock_performance(tickers)
# Out:
# https://www.moneycontrol.com/financials/abbindia/results/yearly/ABB
# https://www.moneycontrol.com/financials/acc/results/consolidated-yearly/ACC06
# https://www.moneycontrol.com/financials/ausmallfinancebank/results/yearly/ASF02
# https://www.moneycontrol.com/financials/aartiindustries/results/consolidated-yearly/AI45
# https://www.moneycontrol.com/financials/thetatapowercompany/results/consolidated-yearly/TPC
# https://www.moneycontrol.com/financials/tatasteel/results/consolidated-yearly/TIS
# https://www.moneycontrol.com/financials/techmahindra/results/consolidated-yearly/TM4
# https://www.moneycontrol.com/financials/theramcocements/results/consolidated-yearly/MC
# https://www.moneycontrol.com/financials/titancompany/results/consolidated-yearly/TI01
# https://www.moneycontrol.com/financials/torrentpharmaceuticals/results/consolidated-yearly/TP06
# https://www.moneycontrol.com/financials/trent/results/consolidated-yearly/T04
# https://www.moneycontrol.com/financials/upl/results/consolidated-yearly/UP04
# https://www.moneycontrol.com/financials/ultratechcement/results/consolidated-yearly/UTC01
# https://www.moneycontrol.com/financials/unitedbreweries/results/consolidated-yearly/UB02
# https://www.moneycontrol.com/financials/unitedspirits/results/consolidated-yearly/US
# https://www.moneycontrol.com/financials/vedanta/results/consolidated-yearly/SG
# https://www.moneycontrol.com/financials/vodafoneidealimited/results/consolidated-yearly/IC8
# https://www.moneycontrol.com/financials/voltas/results/consolidated-yearly/V
# https://www.moneycontrol.com/financials/wipro/results/consolidated-yearly/W
# https://www.moneycontrol.com/financials/zeeentertainmententerprises/results/consolidated-yearly/ZEE
# https://www.moneycontrol.com/financials/zyduslifesciences/results/consolidated-yearly/CHC
# https://www.moneycontrol.com/financials/116/results/consolidated-yearly/CHC
# https://www.moneycontrol.com/financials/157/results/consolidated-yearly/CHC

# %%
res_ics.Stock.nunique()
# Out:
# 176

# %%
pd.read_csv("income_statement.csv").Stock.nunique()
# Out:
# 184

# %%
incs = pd.read_csv("income_statement.csv")
incs[incs["Stock"] == "zyduslifesciences"]
# Out:
#       Unnamed: 0                                                  0         1  \
# 9687           0  Yearly Results of Zydus Lifesciences (in Rs. Cr.)   Mar '23
# 9688           1                   Net Sales/Income from operations  16877.80
# 9689           2                             Other Operating Income    359.60
# 9690           3                       Total Income From Operations  17237.40
# 9691           4                                        EXPENDITURE       NaN
# 9692           5                       Consumption of Raw Materials   4122.60
# 9693           6                           Purchase of Traded Goods   1949.40
# 9694           7                        Increase/Decrease in Stocks    238.10
# 9695           8                                       Power & Fuel        --
# 9696           9                                     Employees Cost   2765.60
# 9697          10                                       Depreciation    722.70
# 9698          11                                        Excise Duty        --
# 9699          12                        Admin. And Selling Expenses        --
# 9700          13                                     R & D Expenses        --
# 9701          14                       Provisions And Contingencies        --
# 9702          15                                   Exp. Capitalised        --
# 9703          16                                     Other Expenses   4301.80
# 9704          17    P/L Before Other Inc., Int., Excpt. Items & Tax   3137.20
# 9705          18                                       Other Income    186.60
# 9706          19                P/L Before Int., Excpt. Items & Tax   3323.80
# 9707          20                                           Interest    129.90
# 9708          21                 P/L Before Exceptional Items & Tax   3193.90
# 9709          22                                  Exceptional Items   -604.20
# 9710          23                                     P/L Before Tax   2589.70
# 9711          24                                                Tax    587.80
# 9712          25             P/L After Tax from Ordinary Activities   2001.90
# 9713          26                             Prior Year Adjustments        --
# 9714          27                               Extra Ordinary Items     -4.60
# 9715          28                   Net Profit/(Loss) For the Period   1997.30
# 9716          29                                  Minority Interest   -131.60
# 9717          30                         Share Of P/L Of Associates     94.60
# 9718          31                     Net P/L After M.I & Associates   1960.30
# 9719          32                               Equity Share Capital    101.20
# 9720          33            Reserves Excluding Revaluation Reserves  17414.60
# 9721          34                           Equity Dividend Rate (%)        --
# 9722          35                          EPS Before Extra Ordinary       NaN
# 9723          36                                          Basic EPS     19.30
# 9724          37                                        Diluted EPS     19.30
# 9725          38                           EPS After Extra Ordinary       NaN
# 9726          39                                         Basic EPS.     19.30
# 9727          40                                       Diluted EPS.     19.30
# 9728          41                               Public Share Holding       NaN
# 9729          42                              No Of Shares (Crores)        --
# 9730          43                                  Share Holding (%)        --
# 9731          44          Promoters and Promoter Group Shareholding       NaN
# 9732          45                              a) Pledged/Encumbered       NaN
# 9733          46                        - Number of shares (Crores)        --
# 9734          47  - Per. of shares (as a % of the total sh. of p...        --
# 9735          48  - Per. of shares (as a % of the total Share Ca...        --
# 9736          49                                  b) Non-encumbered       NaN
# 9737          50                       - Number of shares (Crores).        --
# 9738          51  - Per. of shares (as a % of the total sh. of p...        --
# 9739          52  - Per. of shares (as a % of the total Share Ca...        --
#
#              2         3         4         5   6              Stock
# 9687   Mar '22   Mar '21   Mar '20   Mar '19 NaN  zyduslifesciences
# 9688  14827.60  15102.20  14253.10  12748.40 NaN  zyduslifesciences
# 9689    437.60        --        --    417.20 NaN  zyduslifesciences
# 9690  15265.20  15102.20  14253.10  13165.60 NaN  zyduslifesciences
# 9691       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 9692   4042.90   3888.20   3459.60   2674.10 NaN  zyduslifesciences
# 9693   1864.60   1471.10   1554.20   2152.00 NaN  zyduslifesciences
# 9694   -362.30   -149.20    -93.80   -109.70 NaN  zyduslifesciences
# 9695        --        --        --        -- NaN  zyduslifesciences
# 9696   2434.10   2490.20   2414.50   2124.10 NaN  zyduslifesciences
# 9697    713.00    724.80    696.50    598.60 NaN  zyduslifesciences
# 9698        --        --        --        -- NaN  zyduslifesciences
# 9699        --        --        --        -- NaN  zyduslifesciences
# 9700        --        --        --        -- NaN  zyduslifesciences
# 9701        --        --        --        -- NaN  zyduslifesciences
# 9702        --        --        --        -- NaN  zyduslifesciences
# 9703   3945.20   4060.90   4135.20   3352.00 NaN  zyduslifesciences
# 9704   2627.70   2616.20   2086.90   2374.50 NaN  zyduslifesciences
# 9705    224.70     37.20    113.90    201.10 NaN  zyduslifesciences
# 9706   2852.40   2653.40   2200.80   2575.60 NaN  zyduslifesciences
# 9707    127.00    163.50    341.80    193.50 NaN  zyduslifesciences
# 9708   2725.40   2489.90   1859.00   2382.10 NaN  zyduslifesciences
# 9709    112.70   -205.10   -363.60        -- NaN  zyduslifesciences
# 9710   2838.10   2284.80   1495.40   2382.10 NaN  zyduslifesciences
# 9711    511.70    147.20    319.80    530.30 NaN  zyduslifesciences
# 9712   2326.40   2137.60   1175.60   1851.80 NaN  zyduslifesciences
# 9713        --        --        --        -- NaN  zyduslifesciences
# 9714   2245.70        --        --        -- NaN  zyduslifesciences
# 9715   4572.10   2137.60   1175.60   1851.80 NaN  zyduslifesciences
# 9716   -131.00    -51.40    -27.80    -49.90 NaN  zyduslifesciences
# 9717     46.20     47.40     28.80     46.90 NaN  zyduslifesciences
# 9718   4487.30   2133.60   1176.60   1848.80 NaN  zyduslifesciences
# 9719    102.40    102.40    102.40    102.40 NaN  zyduslifesciences
# 9720  16897.20  12889.90  10273.30  10283.90 NaN  zyduslifesciences
# 9721        --        --        --        -- NaN  zyduslifesciences
# 9722       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 9723     43.83     20.84     11.49     18.06 NaN  zyduslifesciences
# 9724     43.83     20.84     11.49     18.06 NaN  zyduslifesciences
# 9725       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 9726     43.83     20.84     11.49     18.06 NaN  zyduslifesciences
# 9727     43.83     20.84     11.49     18.06 NaN  zyduslifesciences
# 9728       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 9729        --        --        --        -- NaN  zyduslifesciences
# 9730        --        --        --        -- NaN  zyduslifesciences
# 9731       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 9732       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 9733        --        --        --        -- NaN  zyduslifesciences
# 9734        --        --        --        -- NaN  zyduslifesciences
# 9735        --        --        --        -- NaN  zyduslifesciences
# 9736       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 9737        --        --        --        -- NaN  zyduslifesciences
# 9738        --        --        --        -- NaN  zyduslifesciences
# 9739        --        --        --        -- NaN  zyduslifesciences

# %%
import pandas as pd
import requests


def PnL(ticker, ti):

    url = 'https://www.moneycontrol.com/financials/{}/consolidated-profit-lossVI/{}'.format(ticker, ti)
    print(url)
    df = pd.read_html(requests.post(url).text)[0]

    return df


def PnL_alternate(ticker, ti):

    url = 'https://www.moneycontrol.com/financials/{}/profit-lossVI/{}'.format(ticker, ti)
    print(url)
    df = pd.read_html(requests.post(url).text)[0]

    return df

def run_stock_performance(tickers):
    fin = []
    missing_pnl = []
    for i in range(len(tickers)):
        try:
            if tickers[i] in ticker_alternate:
                df = pd.DataFrame()
                df = PnL_alternate(tickers[i], ti[i])
                df["Stock"] = tickers[i]
                fin.append(df)
            else:

                df = pd.DataFrame()
                df = PnL(tickers[i], ti[i])
                df["Stock"] = tickers[i]
                fin.append(df)
        except:
            missing_pnl.append(i)

    for i in missing_pnl:
        if tickers[i] in ticker_alternate:
            df = pd.DataFrame()
            df = PnL_alternate(tickers[i], ti[i])
            df["Stock"] = tickers[i]
            fin.append(df)
        else:

            df = pd.DataFrame()
            df = PnL(tickers[i], ti[i])
            df["Stock"] = tickers[i]
            fin.append(df)

    pl = pd.concat(fin)
    return pl

# %%
res_pl = run_stock_performance(tickers)
# Out:
# https://www.moneycontrol.com/financials/abbindia/profit-lossVI/ABB
# https://www.moneycontrol.com/financials/acc/consolidated-profit-lossVI/ACC06
# https://www.moneycontrol.com/financials/ausmallfinancebank/profit-lossVI/ASF02
# https://www.moneycontrol.com/financials/aartiindustries/consolidated-profit-lossVI/AI45
# https://www.moneycontrol.com/financials/abbottindia/profit-lossVI/AI51
# https://www.moneycontrol.com/financials/adanienterprises/consolidated-profit-lossVI/AE13
# https://www.moneycontrol.com/financials/adaniportsspecialeconomiczone/consolidated-profit-lossVI/MPS
# https://www.moneycontrol.com/financials/adityabirlacapital/consolidated-profit-lossVI/ABC9
# https://www.moneycontrol.com/financials/adityabirlafashionretail/consolidated-profit-lossVI/PFR
# https://www.moneycontrol.com/financials/alkemlaboratories/consolidated-profit-lossVI/AL05
# https://www.moneycontrol.com/financials/tatamotors/consolidated-profit-lossVI/TM03
# https://www.moneycontrol.com/financials/thetatapowercompany/consolidated-profit-lossVI/TPC
# https://www.moneycontrol.com/financials/tatasteel/consolidated-profit-lossVI/TIS
# https://www.moneycontrol.com/financials/techmahindra/consolidated-profit-lossVI/TM4
# https://www.moneycontrol.com/financials/theramcocements/consolidated-profit-lossVI/MC
# https://www.moneycontrol.com/financials/titancompany/consolidated-profit-lossVI/TI01
# https://www.moneycontrol.com/financials/torrentpharmaceuticals/consolidated-profit-lossVI/TP06
# https://www.moneycontrol.com/financials/trent/consolidated-profit-lossVI/T04
# https://www.moneycontrol.com/financials/upl/consolidated-profit-lossVI/UP04
# https://www.moneycontrol.com/financials/ultratechcement/consolidated-profit-lossVI/UTC01
# https://www.moneycontrol.com/financials/unitedbreweries/consolidated-profit-lossVI/UB02
# https://www.moneycontrol.com/financials/unitedspirits/consolidated-profit-lossVI/US
# https://www.moneycontrol.com/financials/vedanta/consolidated-profit-lossVI/SG
# https://www.moneycontrol.com/financials/vodafoneidealimited/consolidated-profit-lossVI/IC8
# https://www.moneycontrol.com/financials/voltas/consolidated-profit-lossVI/V
# https://www.moneycontrol.com/financials/wipro/consolidated-profit-lossVI/W
# https://www.moneycontrol.com/financials/zeeentertainmententerprises/consolidated-profit-lossVI/ZEE
# https://www.moneycontrol.com/financials/157/consolidated-profit-lossVI/CHC
# https://www.moneycontrol.com/financials/107/consolidated-profit-lossVI/MG02
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [40], in <cell line: 1>()
# ----> 1 res_pl = run_stock_performance(tickers)
#
# Input In [37], in run_stock_performance(tickers)
#      47 else:
#      49     df = pd.DataFrame()
# ---> 50     df = PnL(tickers[i], ti[i])
#      51     df["Stock"] = tickers[i]
#      52     fin.append(df)
#
# Input In [37], in PnL(ticker, ti)
#       7 url = 'https://www.moneycontrol.com/financials/{}/consolidated-profit-lossVI/{}'.format(ticker, ti)
#       8 print(url)
# ----> 9 df = pd.read_html(requests.post(url).text)[0]
#      11 return df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:1113, in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1109 validate_header_arg(header)
#    1111 io = stringify_path(io)
# -> 1113 return _parse(
#    1114     flavor=flavor,
#    1115     io=io,
#    1116     match=match,
#    1117     header=header,
#    1118     index_col=index_col,
#    1119     skiprows=skiprows,
#    1120     parse_dates=parse_dates,
#    1121     thousands=thousands,
#    1122     attrs=attrs,
#    1123     encoding=encoding,
#    1124     decimal=decimal,
#    1125     converters=converters,
#    1126     na_values=na_values,
#    1127     keep_default_na=keep_default_na,
#    1128     displayed_only=displayed_only,
#    1129 )
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:939, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     937 else:
#     938     assert retained is not None  # for mypy
# --> 939     raise retained
#     941 ret = []
#     942 for table in tables:
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:919, in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     916 p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     918 try:
# --> 919     tables = p.parse_tables()
#     920 except ValueError as caught:
#     921     # if `io` is an io-like object, check if it's seekable
#     922     # and try to rewind it before trying the next parser
#     923     if hasattr(io, "seekable") and io.seekable():
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:239, in _HtmlFrameParser.parse_tables(self)
#     231 def parse_tables(self):
#     232     """
#     233     Parse and return all tables from the DOM.
#     234
#    (...)
#     237     list of parsed (header, body, footer) tuples from tables.
#     238     """
# --> 239     tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     240     return (self._parse_thead_tbody_tfoot(table) for table in tables)
#
# File ~\anaconda3\lib\site-packages\pandas\io\html.py:585, in _BeautifulSoupHtml5LibFrameParser._parse_tables(self, doc, match, attrs)
#     582     unique_tables.add(table)
#     584 if not result:
# --> 585     raise ValueError(f"No tables found matching pattern {repr(match.pattern)}")
#     586 return result
#
# ValueError: No tables found matching pattern '.+'

# %%
pl = pd.read_csv("pnl.csv")
pl[pl["Stock"] == "zyduslifesciences"]
# Out:
#       Unnamed: 0                                                  0         1  \
# 7347           0  Profit & Loss account of Zydus Lifesciences (i...    Mar 23
# 7348           1                                                NaN   12 mths
# 7349           2                                             INCOME       NaN
# 7350           3                    Revenue From Operations [Gross]  16877.80
# 7351           4               Less: Excise/Sevice Tax/Other Levies      0.00
# 7352           5                      Revenue From Operations [Net]  16877.80
# 7353           6                           Total Operating Revenues  17237.40
# 7354           7                                       Other Income    186.60
# 7355           8                                      Total Revenue  17424.00
# 7356           9                                           EXPENSES       NaN
# 7357          10                         Cost Of Materials Consumed   4122.60
# 7358          11                         Purchase Of Stock-In Trade   1949.40
# 7359          12                      Operating And Direct Expenses      0.00
# 7360          13  Changes In Inventories Of FGWIP And Stock In T...    238.10
# 7361          14                          Employee Benefit Expenses   2765.60
# 7362          15                                      Finance Costs    129.90
# 7363          16             Depreciation And Amortisation Expenses    722.70
# 7364          17                                     Other Expenses   4301.80
# 7365          18                                     Total Expenses  14230.10
# 7366          19  Profit/Loss Before Exceptional, ExtraOrdinary ...   3193.90
# 7367          20                                  Exceptional Items   -604.20
# 7368          21                             Profit/Loss Before Tax   2589.70
# 7369          22                  Tax Expenses-Continued Operations       NaN
# 7370          23                                        Current Tax    690.40
# 7371          24                       Less: MAT Credit Entitlement      0.00
# 7372          25                                       Deferred Tax   -102.60
# 7373          26                                 Other Direct Taxes      0.00
# 7374          27                                 Total Tax Expenses    587.80
# 7375          28  Profit/Loss After Tax And Before ExtraOrdinary...   2001.90
# 7376          29             Profit/Loss From Continuing Operations   2001.90
# 7377          30                         Profit/Loss For The Period   1997.30
# 7378          31                                  Minority Interest   -131.60
# 7379          32   Consolidated Profit/Loss After MI And Associates   1960.30
# 7380          33                       OTHER ADDITIONAL INFORMATION       NaN
# 7381          34                                 EARNINGS PER SHARE       NaN
# 7382          35                                    Basic EPS (Rs.)     19.00
# 7383          36                                  Diluted EPS (Rs.)     19.00
# 7384          37                   DIVIDEND AND DIVIDEND PERCENTAGE       NaN
# 7385          38                              Equity Share Dividend    266.50
# 7386          39                                    Tax On Dividend      0.00
#
#              2         3         4         5   6              Stock
# 7347    Mar 22    Mar 21    Mar 20    Mar 19 NaN  zyduslifesciences
# 7348   12 mths   12 mths   12 mths   12 mths NaN  zyduslifesciences
# 7349       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 7350  14827.60  14125.00  13812.10  12748.40 NaN  zyduslifesciences
# 7351      0.00      0.00      0.00      0.00 NaN  zyduslifesciences
# 7352  14827.60  14125.00  13812.10  12748.40 NaN  zyduslifesciences
# 7353  15265.20  14403.50  14253.10  13165.60 NaN  zyduslifesciences
# 7354    224.70     45.60    113.90    201.10 NaN  zyduslifesciences
# 7355  15489.90  14449.10  14367.00  13366.70 NaN  zyduslifesciences
# 7356       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 7357   4042.90   3669.00   3459.60   2674.10 NaN  zyduslifesciences
# 7358   1864.60   1289.30   1554.20   2152.00 NaN  zyduslifesciences
# 7359      0.00      0.00      0.00      0.00 NaN  zyduslifesciences
# 7360   -362.30   -156.20    -93.80   -109.70 NaN  zyduslifesciences
# 7361   2434.10   2295.10   2395.80   2124.10 NaN  zyduslifesciences
# 7362    127.00    158.80    341.80    193.50 NaN  zyduslifesciences
# 7363    713.00    669.60    696.50    598.60 NaN  zyduslifesciences
# 7364   3945.20   3919.20   4153.90   3341.60 NaN  zyduslifesciences
# 7365  12764.50  11844.80  12508.00  10974.20 NaN  zyduslifesciences
# 7366   2725.40   2604.30   1859.00   2392.50 NaN  zyduslifesciences
# 7367    112.70   -205.10   -363.60    -10.40 NaN  zyduslifesciences
# 7368   2838.10   2399.20   1495.40   2382.10 NaN  zyduslifesciences
# 7369       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 7370    441.50    453.00    237.70    607.30 NaN  zyduslifesciences
# 7371      0.00      0.00      0.00      0.00 NaN  zyduslifesciences
# 7372     70.20   -259.40     82.10    -77.00 NaN  zyduslifesciences
# 7373      0.00      0.00      0.00      0.00 NaN  zyduslifesciences
# 7374    511.70    193.60    319.80    530.30 NaN  zyduslifesciences
# 7375   2326.40   2205.60   1175.60   1851.80 NaN  zyduslifesciences
# 7376   2326.40   2205.60   1175.60   1851.80 NaN  zyduslifesciences
# 7377   4572.10   2137.60   1175.60   1851.80 NaN  zyduslifesciences
# 7378   -131.00    -51.40    -27.80    -49.90 NaN  zyduslifesciences
# 7379   4487.30   2133.60   1176.60   1848.80 NaN  zyduslifesciences
# 7380       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 7381       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 7382     44.00     21.00     11.00     18.00 NaN  zyduslifesciences
# 7383     44.00     21.00     11.00     18.00 NaN  zyduslifesciences
# 7384       NaN       NaN       NaN       NaN NaN  zyduslifesciences
# 7385    372.00      0.00    716.60    358.30 NaN  zyduslifesciences
# 7386      0.00      0.00    140.30     73.10 NaN  zyduslifesciences

# %%
pl.Stock.nunique()
# Out:
# 184

# %%
pd.read_csv("balance_sheet.csv")["Stock"].nunique()
# Out:
# 184

# %% [markdown]
# #### Result

# %%
bs = pd.read_csv("balance_sheet.csv")
cfs = pd.read_csv("cash_flow.csv")
gen_stock = pd.read_csv("general_performance.csv")
incs = pd.read_csv("income_statement.csv")
pl = pd.read_csv("pnl.csv")

# %%
def rename_col(df):
    #     df.columns = df.iloc[0]
    if df.shape[1] > 8:
        df = df.drop(df.columns[0], axis=1)

    df.columns = ["Attribute", "First Date", "Second Date", "Third Date", "Fourth Date ", "Fifth Date", "Blank",
                  "Stock"]
    #     df = df[2:]
    return df


def operation(financial_fin, st, year):
    fin = {}
    financial_fin_st = financial_fin[financial_fin["Stock"] == st]
    financial_fin_st_T = financial_fin_st.transpose()
    #     financial_fin_st_T = financial_fin_st_T.reset_index(drop=True)

    financial_fin_st_T.columns = financial_fin_st_T.iloc[0]
    financial_fin_st_T = financial_fin_st_T[1:-3]
    financial_fin_st_T["Stock"] = st
    financial_fin_st_T_selected = financial_fin_st_T[financial_fin_st_T.iloc[:, 0].str.contains(year)]
    financial_fin_st_T_selected.reset_index(drop=True)
    #     if len(financial_fin_st_T_selected) > 0:
    financial_fin_st_T_selected["Year"] = year
    for i in ["Year", "Total Assets", "Stock", "Minority Interest", "Net CashFlow From Operating Activities",
              "Total Shareholders Funds", "Total Current Assets", "Cash And Cash Equivalents", "Current Investments",
              "Total Current Liabilities"
        , "Long Term Borrowings", "Short Term Borrowings",
              "Profit/Loss Before Exceptional, ExtraOrdinary Items And Tax", "Finance Costs", "Other Income",
              "Net CashFlow From Operating Activities", "Net Cash Used In Investing Activities", "Inventories"]:
        if i in financial_fin_st_T_selected.columns:

            fin[i] = financial_fin_st_T_selected[i].iloc[0]
        else:
            fin[i] = ""

    return fin


def stock_df_creation(financial_fin, stock, year):
    af = operation(financial_fin, stock, year)
    df = pd.DataFrame.from_dict(af, orient='index', columns=['Value'])

    df.reset_index(inplace=True)
    df.rename(columns={'index': 'Key'}, inplace=True)
    transposed_df = df.transpose()
    transposed_df.columns = transposed_df.iloc[0]
    transposed_df = transposed_df[1:]

    return transposed_df

def cleaning_func(bs,pl,cfs,incs):
    bs_rename = rename_col(bs)
    pl_rename = rename_col(pl)
    cfs_rename = rename_col(cfs)
    incs_rename =rename_col(incs)

    financial_fin = pd.concat([bs_rename, pl_rename, cfs_rename, incs_rename])

    financial_fin = financial_fin.drop_duplicates()

    stock_list = financial_fin["Stock"].unique()

    return stock_list, financial_fin

def final_dataframe(stock_list,financial_fin ):
    fin = pd.DataFrame()
    missing = []

    for i in stock_list:
        print(i)
        try:
            res = stock_df_creation(financial_fin, i,"23")
            fin = pd.concat([fin,res])
        except:
            missing.append(i)
    return fin, missing

# %%
financial_fin[financial_fin["Stock"] == "nestleindia"]
# Out:
#                                               Attribute First Date  \
# 6858         Balance Sheet of Nestle India (in Rs. Cr.)     Dec 22
# 6859                                                NaN    12 mths
# 6860                           EQUITIES AND LIABILITIES        NaN
# 6861                                SHAREHOLDER'S FUNDS        NaN
# 6862                               Equity Share Capital      96.42
# ...                                                 ...        ...
# 6982  - Per. of shares (as a % of the total Share Ca...         --
# 6983                                  b) Non-encumbered        NaN
# 6984                       - Number of shares (Crores).         --
# 6985  - Per. of shares (as a % of the total sh. of p...         --
# 6986  - Per. of shares (as a % of the total Share Ca...         --
#
#      Second Date Third Date Fourth Date  Fifth Date  Blank        Stock
# 6858      Dec 21     Dec 20       Dec 19     Dec 18    NaN  nestleindia
# 6859     12 mths    12 mths      12 mths    12 mths    NaN  nestleindia
# 6860         NaN        NaN          NaN        NaN    NaN  nestleindia
# 6861         NaN        NaN          NaN        NaN    NaN  nestleindia
# 6862       96.42      96.42        96.42      96.42    NaN  nestleindia
# ...          ...        ...          ...        ...    ...          ...
# 6982          --         --           --         --    NaN  nestleindia
# 6983         NaN        NaN          NaN        NaN    NaN  nestleindia
# 6984          --         --           --         --    NaN  nestleindia
# 6985          --         --           --         --    NaN  nestleindia
# 6986          --         --           --         --    NaN  nestleindia
#
# [166 rows x 8 columns]

# %%
# stock_df_creation(financial_fin, "abbindia","23")
'colgatepalmoliveindia',
 'lichousingfinance',
 'nestleindia',
 'siemens']

# %%
def gen_stock_flat(gen_stock,i):
#     for i in gen_stock["Stock"].unique():
    gen_stock_selected = gen_stock[gen_stock["Stock"] == i]
    gen_stock_selected = gen_stock_selected.drop(["Stock","Unnamed: 0"], axis = 1)
    gen_stock_selected_transpose = gen_stock_selected.T

    gen_stock_selected_transpose.columns = gen_stock_selected_transpose.iloc[0]
    gen_stock_selected_transpose = gen_stock_selected_transpose[1:]

    gen_stock_selected_transpose["Stock"] = i
    gen_stock_selected_transpose = gen_stock_selected_transpose.reset_index(drop= True, inplace=True)

    gen_stock_selected_transpose = gen_stock_selected_transpose[["Stock","Dividend Yield", "Mkt Cap (Rs. Cr.)","TTM EPS See historical trend","Open"]]
#         print(gen_stock_selected_transpose.shape)
    return gen_stock_selected_transpose

# %%
def gen_stock_flat(gen_stock,i):
    
    st = pd.DataFrame()
    gen_stock_selected = gen_stock[gen_stock["Stock"] == i]
    # ["Stock","Dividend Yield", "Mkt Cap (Rs. Cr.)","TTM EPS See historical trend","Open"]
    st["Dividend Yield"] = gen_stock_selected[gen_stock_selected["Value"] == "Dividend Yield"]["Num"].values
    st["Mkt Cap (Rs. Cr.)"] = gen_stock_selected[gen_stock_selected["Value"] == "Mkt Cap (Rs. Cr.)"]["Num"].values
    st["TTM EPS See historical trend"] = gen_stock_selected[gen_stock_selected["Value"] == "TTM EPS See historical trend"]["Num"].values
    st["Open"] = gen_stock_selected[gen_stock_selected["Value"] == "Open"]["Num"].values[0]
    st["Stock"] = i

    return st

# %%
def metric_creation(bs,cfs, incs,pl):
    stock_list, financial_fin = cleaning_func(bs, pl, cfs, incs)
    fin, missing = final_dataframe(stock_list, financial_fin)

    fin = fin.reset_index(drop=True)

    fin["Total Current Assets"] = pd.to_numeric(fin["Total Current Assets"].values, errors='coerce')
    fin["Cash And Cash Equivalents"] = pd.to_numeric(fin["Cash And Cash Equivalents"].values, errors='coerce')
    fin["Current Investments"] = pd.to_numeric(fin["Current Investments"].values, errors='coerce')

    fin["Total Current Liabilities"] = pd.to_numeric(fin["Total Current Liabilities"].values, errors='coerce')

    fin["Short Term Borrowings"] = pd.to_numeric(fin["Short Term Borrowings"].values, errors='coerce')

    fin["Total Shareholders Funds"] = pd.to_numeric(fin["Total Shareholders Funds"].values, errors='coerce')

    fin["Profit/Loss Before Exceptional, ExtraOrdinary Items And Tax"] = pd.to_numeric(
        fin["Profit/Loss Before Exceptional, ExtraOrdinary Items And Tax"].values, errors='coerce')
    fin["Finance Costs"] = pd.to_numeric(fin["Finance Costs"].values, errors='coerce')

    fin["Total Shareholders Funds"] = pd.to_numeric(fin["Total Shareholders Funds"].values, errors='coerce')
    fin["Short Term Borrowings"] = pd.to_numeric(fin["Short Term Borrowings"].values, errors='coerce')

    fin["Long Term Borrowings"] = pd.to_numeric(fin["Long Term Borrowings"].values, errors='coerce')
    fin["Cash And Cash Equivalents"] = pd.to_numeric(fin["Cash And Cash Equivalents"].values, errors='coerce')

    fin["Current Assets"] = fin["Total Current Assets"] - fin["Cash And Cash Equivalents"] - fin["Current Investments"]
    fin["Current Liabilities"] = fin["Total Current Liabilities"] - fin["Short Term Borrowings"]
    fin["Working Capital"] = fin["Current Assets"] - fin["Current Liabilities"]

    ### Dropna removed as a test
#     fin = fin.dropna()

    fin = fin[fin['Minority Interest'].str.strip() != '']

    fin = fin.reset_index(drop=True)

    fin['Minority Interest Balance Sheet'] = ""
    for i in range(fin.shape[0]):
        fin['Minority Interest Balance Sheet'][i] = fin['Minority Interest'][i][0]

    fin['Other Income PnL'] = -1
    for i in range(fin.shape[0]):
        try:
            fin['Other Income PnL'][i] = fin['Other Income'][i].values[0]
        except:
            fin['Other Income PnL'][i] = fin['Other Income'][i]

    fin["EBIT"] = fin["Profit/Loss Before Exceptional, ExtraOrdinary Items And Tax"].astype("float") + \
                       fin["Finance Costs"].astype("float") - fin["Other Income PnL"].astype("float")

    fin["ROC"] = fin["EBIT"].astype("float") / (
                fin["Total Shareholders Funds"].astype("float") + fin["Short Term Borrowings"].astype(
            "float") + fin["Long Term Borrowings"].astype("float") - fin["Cash And Cash Equivalents"].astype(
            "float"))

    return fin

# %%
stock_list, financial_fin = cleaning_func(bs, pl, cfs, incs)
fin, missing = final_dataframe(stock_list, financial_fin)

# fin = fin.reset_index(drop=True)

fin["Total Current Assets"] = pd.to_numeric(fin["Total Current Assets"].values, errors='coerce')
fin["Cash And Cash Equivalents"] = pd.to_numeric(fin["Cash And Cash Equivalents"].values, errors='coerce')
fin["Current Investments"] = pd.to_numeric(fin["Current Investments"].values, errors='coerce')

fin["Total Current Liabilities"] = pd.to_numeric(fin["Total Current Liabilities"].values, errors='coerce')

fin["Short Term Borrowings"] = pd.to_numeric(fin["Short Term Borrowings"].values, errors='coerce')

fin["Total Shareholders Funds"] = pd.to_numeric(fin["Total Shareholders Funds"].values, errors='coerce')

fin["Profit/Loss Before Exceptional, ExtraOrdinary Items And Tax"] = pd.to_numeric(
    fin["Profit/Loss Before Exceptional, ExtraOrdinary Items And Tax"].values, errors='coerce')
fin["Finance Costs"] = pd.to_numeric(fin["Finance Costs"].values, errors='coerce')

fin["Total Shareholders Funds"] = pd.to_numeric(fin["Total Shareholders Funds"].values, errors='coerce')
fin["Short Term Borrowings"] = pd.to_numeric(fin["Short Term Borrowings"].values, errors='coerce')

fin["Long Term Borrowings"] = pd.to_numeric(fin["Long Term Borrowings"].values, errors='coerce')
fin["Cash And Cash Equivalents"] = pd.to_numeric(fin["Cash And Cash Equivalents"].values, errors='coerce')

fin["Current Assets"] = fin["Total Current Assets"] - fin["Cash And Cash Equivalents"] - fin["Current Investments"]
fin["Current Liabilities"] = fin["Total Current Liabilities"] - fin["Short Term Borrowings"]
fin["Working Capital"] = fin["Current Assets"] - fin["Current Liabilities"]
# Out:
# abbindia
# acc
# ausmallfinancebank
# aartiindustries
# abbottindia
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# adanienterprises
# adaniportsspecialeconomiczone
# adityabirlacapital
# adityabirlafashionretail
# alkemlaboratories
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# ambujacements
# apollohospitalsenterprises
# apollotyres
# ashokleyland
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# asianpaints
# astrallimited
# atul
# aurobindopharma
# axisbank
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# bajajauto
# bajajfinance
# bajajfinserv
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# balkrishnaindustries
# balrampurchinimills
# bandhanbank
# bankbaroda
# bataindia
# bergerpaintsindia
# bharatelectronics
# bharatforge
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# bharatheavyelectricals
# bharatpetroleumcorporation
# bhartiairtel
# biocon
# birlasoft
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# bosch
# britanniaindustries
# canfinhomes
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# canarabank
# chambalfertiliserschemicals
# cholamandalaminvestmentfinancecompany
# cipla
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# cityunionbank
# coalindia
# coforgelimited
# colgatepalmoliveindia
# containercorporationindia
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# coromandelinternational
# cromptongreavesconsumerelectrical
# cumminsindia
# dlf
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# daburindia
# dalmiabharat
# deepaknitrite
# deltacorp
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# divislaboratories
# dixontechnologies
# drlalpathlabs
# drreddyslaboratories
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# eichermotors
# escortskubota
# exideindustries
# federalbank
# gailindia
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# gmrairportsinfrastructure
# glenmarkpharma
# godrejconsumerproducts
# godrejproperties
# granulesindia
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# grasimindustries
# gujaratgas
# gujaratnarmadavalleyfertchem
# hcltechnologies
# hdfcassetmanagementcompany
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# hdfcbank
# hdfclifeinsurancecompany
# havellsindia
# heromotocorp
# hindalcoindustries
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# hindustanaeronauticsltd
# hindustancopper
# hindustanpetroleumcorporation
# hindustanunilever
# icicibank
# icicilombardgeneralinsurancecompany
# iciciprudentiallifeinsurancecompany
# idfcfirstbank
# idfc
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# itc
# indiacements
# indiabullshousingfinance
# indiamartintermesh
# indianenergyexchange
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# indianhotelscompany
# indianoilcorporation
# irctc-indianrailwaycateringtourismcorp
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# indraprasthagas
# industowers
# indusindbank
# infoedgeindia
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# infosys
# interglobeaviation
# ipcalaboratories
# jkcement
# jswsteel
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# jindalsteelpower
# jubilantfoodworks
# kotakmahindrabank
# ltfinanceholdings
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# lttechnologyservices
# lichousingfinance
# ltimindtree
# larsentoubro
# lauruslabs
# lupin
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# mrf
# mahanagargas
# mahindramahindrafinancialservices
# mahindramahindra
# manappuramfinance
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# sbicardspaymentservices
# sbilifeinsurancecompany
# srf
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# samvardhanamothersoninternational
# shreecements
# shriramfinance
# siemens
# statebankindia
# steelauthorityindia
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# sunpharmaceuticalindustries
# suntvnetwork
# syngeneinternational
# tvsmotorcompany
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# tatachemicals
# tatacommunications
# tataconsultancyservices
# tataconsumerproducts
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# tatamotors
# thetatapowercompany
# tatasteel
# techmahindra
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# theramcocements
# titancompany
# torrentpharmaceuticals
# trent
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# upl
# ultratechcement
# unitedbreweries
# unitedspirits
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# vedanta
# vodafoneidealimited
# voltas
# wipro
# zeeentertainmententerprises
# zyduslifesciences
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year

# %%
fin.Stock.nunique()
# Out:
# 179

# %%
missing
# Out:
# ['abbindia',
#  'colgatepalmoliveindia',
#  'lichousingfinance',
#  'nestleindia',
#  'siemens']

# %%
fin = fin[fin['Minority Interest'].str.strip() != '']

# fin = fin.reset_index(drop=True)

# fin['Minority Interest Balance Sheet'] = ""
# for i in range(fin.shape[0]):
#     fin['Minority Interest Balance Sheet'][i] = fin['Minority Interest'][i][0]
# fin['Minority Interest Balance Sheet'] = -1

# fin['Other Income PnL'] = -1
# for i in range(fin.shape[0]):
#     try:
#         fin['Other Income PnL'][i] = fin['Other Income'][i].values[0]
#     except:
#         fin['Other Income PnL'][i] = fin['Other Income'][i]

# %%
# for i in range(fin.shape[0]):
#     print(i)
#     print(fin['Minority Interest'][i][0])

# %%
fin.shape[0]
# Out:
# 179

# %%
import numpy as np
import re

def extract_first_integer(s):
    try:
        if isinstance(s, str):
            return s
        else:
            return s[0]
    except:
        return np.nan
    
#     if isinstance(s, str):
#         print("yes")
#         numbers = re.findall(r"[-+]?\d*\.\d+|\d+", s)
#         if numbers:
#             return float(numbers[0])
#     return np.nan
#         try:
#             return float(s)
#         except ValueError:
#             return np.nan
#     else:
#         return np.nan

# Apply the function to the 'YourColumn' and create a new 'NewColumn'
fin['Minority Interest Balance Sheet'] = fin['Minority Interest'].apply(extract_first_integer)

# %%
# def other_income(s):
#     if isinstance(s, str):
#         return s[0]
#     if isinstance(s, int):
#         return s
#     return np.nan

# %%
# other_income(s)
fin["Other Income Balance Sheet"] = fin['Other Income'].apply(extract_first_integer)
fin
# Out:
# Key   Year Total Assets                        Stock  \
# Value   23     20543.77                          acc
# Value   23     90216.12           ausmallfinancebank
# Value   23      8580.90              aartiindustries
# Value   23      4555.51                  abbottindia
# Value   23    141487.82             adanienterprises
# ...    ...          ...                          ...
# Value   23    207242.70          vodafoneidealimited
# Value   23     10279.01                       voltas
# Value   23    117133.70                        wipro
# Value   23     13728.35  zeeentertainmententerprises
# Value   23     25756.40            zyduslifesciences
#
# Key                                    Minority Interest  \
# Value  Attribute
# Minority Interest     3.48
# Minority ...
# Value
# Value  Attribute
# Minority Interest    0.72
# Minority I...
# Value
# Value  Attribute
# Minority Interest    4839.04
# Minorit...
# ...                                                  ...
# Value  Attribute
# Minority Interest    0.00
# Minority I...
# Value  Attribute
# Minority Interest    41.65
# Minority ...
# Value  Attribute
# Minority Interest     58.90
# Minority...
# Value  Attribute
# Minority Interest    0.00
# Minority I...
# Value  Attribute
# Minority Interest    2172.50
# Minorit...
#
# Key   Net CashFlow From Operating Activities  Total Shareholders Funds  \
# Value                               -1235.08                  14138.47
# Value                                5493.64                       NaN
# Value                                1309.80                   4920.06
# Value                                 893.39                   3188.54
# Value                               17626.46                  31873.89
# ...                                      ...                       ...
# Value                               18868.70                 -74359.10
# Value                                 159.38                   5452.07
# Value                               13060.10                  77667.90
# Value                                 129.05                  10721.87
# Value                                2688.80                  17515.80
#
# Key    Total Current Assets  Cash And Cash Equivalents  Current Investments  \
# Value               8255.15                     414.71                 0.00
# Value                   NaN                        NaN                  NaN
# Value               2459.28                     200.73                 0.00
# Value               3025.11                    1937.06                 0.00
# Value              37121.73                    5373.69               165.00
# ...                     ...                        ...                  ...
# Value              13902.90                     855.40                 0.00
# Value               6446.49                     708.38               307.16
# Value              66109.60                    9188.00             30923.20
# Value              11391.83                     804.02                 0.00
# Value              10016.40                     573.10               619.30
#
# Key    Total Current Liabilities  ...  \
# Value                    5641.01  ...
# Value                        NaN  ...
# Value                    2783.34  ...
# Value                    1206.02  ...
# Value                   44803.05  ...
# ...                          ...  ...
# Value                   60022.70  ...
# Value                    4619.54  ...
# Value                   26775.30  ...
# Value                    2653.56  ...
# Value                    5530.70  ...
#
# Key    Profit/Loss Before Exceptional, ExtraOrdinary Items And Tax  \
# Value                                            1348.22
# Value                                                NaN
# Value                                             611.10
# Value                                            1273.82
# Value                                            3619.22
# ...                                                  ...
# Value                                          -29275.70
# Value                                             671.61
# Value                                           14771.40
# Value                                             803.65
# Value                                            3193.90
#
# Key    Finance Costs                                       Other Income  \
# Value          77.28  Attribute
# Other Income    341.89
# Other Income ...
# Value            NaN  Attribute
# Other Income    1034.46
# Other Income...
# Value         168.28  Attribute
# Other Income    0.86
# Other Income   ...
# Value          15.99                                             154.15
# Value        3969.98                                            1197.36
# ...              ...                                                ...
# Value       23354.30                                             311.30
# Value          29.59                                             168.45
# Value        1007.70                                            2265.70
# Value          70.24  Attribute
# Other Income    79.72
# Other Income  ...
# Value         129.90  Attribute
# Other Income    186.60
# Other Income ...
#
# Key    Net Cash Used In Investing Activities Inventories Current Assets  \
# Value                               -4637.30     1624.20        7840.44
# Value                               -4319.50                        NaN
# Value                               -1329.78     1031.05        2258.55
# Value                                -147.71      648.85        1088.05
# Value                              -16860.09     6918.05       31583.04
# ...                                      ...         ...            ...
# Value                               -5413.60       16.30       13047.50
# Value                                 -81.60     1591.97        5430.95
# Value                               -8406.50      118.80       25998.40
# Value                                -201.58     7307.89       10587.81
# Value                                1171.20     3413.30        8824.00
#
# Key   Current Liabilities  Working Capital  Minority Interest Balance Sheet  \
# Value             5641.01          2199.43                             3.48
# Value                 NaN              NaN
# Value              544.02          1714.53                             0.72
# Value             1206.02          -117.97
# Value            39073.46         -7490.42                          4839.04
# ...                   ...              ...                              ...
# Value            47726.80        -34679.30                             0.00
# Value             4024.72          1406.23                            41.65
# Value            17893.20          8105.20                            58.90
# Value             2651.67          7936.14                             0.00
# Value             4367.50          4456.50                          2172.50
#
# Key    Other Income Balance Sheet
# Value                      341.89
# Value                     1034.46
# Value                        0.86
# Value                      154.15
# Value                     1197.36
# ...                           ...
# Value                      311.30
# Value                      168.45
# Value                     2265.70
# Value                       79.72
# Value                      186.60
#
# [179 rows x 22 columns]

# %%
fin['Other Income Balance Sheet'] = fin['Other Income'].apply(extract_first_integer)

# %%
fin
# Out:
# Key   Year Total Assets                        Stock  \
# Value   23     20543.77                          acc
# Value   23     90216.12           ausmallfinancebank
# Value   23      8580.90              aartiindustries
# Value   23      4555.51                  abbottindia
# Value   23    141487.82             adanienterprises
# ...    ...          ...                          ...
# Value   23    207242.70          vodafoneidealimited
# Value   23     10279.01                       voltas
# Value   23    117133.70                        wipro
# Value   23     13728.35  zeeentertainmententerprises
# Value   23     25756.40            zyduslifesciences
#
# Key                                    Minority Interest  \
# Value  Attribute
# Minority Interest     3.48
# Minority ...
# Value
# Value  Attribute
# Minority Interest    0.72
# Minority I...
# Value
# Value  Attribute
# Minority Interest    4839.04
# Minorit...
# ...                                                  ...
# Value  Attribute
# Minority Interest    0.00
# Minority I...
# Value  Attribute
# Minority Interest    41.65
# Minority ...
# Value  Attribute
# Minority Interest     58.90
# Minority...
# Value  Attribute
# Minority Interest    0.00
# Minority I...
# Value  Attribute
# Minority Interest    2172.50
# Minorit...
#
# Key   Net CashFlow From Operating Activities  Total Shareholders Funds  \
# Value                               -1235.08                  14138.47
# Value                                5493.64                       NaN
# Value                                1309.80                   4920.06
# Value                                 893.39                   3188.54
# Value                               17626.46                  31873.89
# ...                                      ...                       ...
# Value                               18868.70                 -74359.10
# Value                                 159.38                   5452.07
# Value                               13060.10                  77667.90
# Value                                 129.05                  10721.87
# Value                                2688.80                  17515.80
#
# Key    Total Current Assets  Cash And Cash Equivalents  Current Investments  \
# Value               8255.15                     414.71                 0.00
# Value                   NaN                        NaN                  NaN
# Value               2459.28                     200.73                 0.00
# Value               3025.11                    1937.06                 0.00
# Value              37121.73                    5373.69               165.00
# ...                     ...                        ...                  ...
# Value              13902.90                     855.40                 0.00
# Value               6446.49                     708.38               307.16
# Value              66109.60                    9188.00             30923.20
# Value              11391.83                     804.02                 0.00
# Value              10016.40                     573.10               619.30
#
# Key    Total Current Liabilities  ...  \
# Value                    5641.01  ...
# Value                        NaN  ...
# Value                    2783.34  ...
# Value                    1206.02  ...
# Value                   44803.05  ...
# ...                          ...  ...
# Value                   60022.70  ...
# Value                    4619.54  ...
# Value                   26775.30  ...
# Value                    2653.56  ...
# Value                    5530.70  ...
#
# Key    Profit/Loss Before Exceptional, ExtraOrdinary Items And Tax  \
# Value                                            1348.22
# Value                                                NaN
# Value                                             611.10
# Value                                            1273.82
# Value                                            3619.22
# ...                                                  ...
# Value                                          -29275.70
# Value                                             671.61
# Value                                           14771.40
# Value                                             803.65
# Value                                            3193.90
#
# Key    Finance Costs                                       Other Income  \
# Value          77.28  Attribute
# Other Income    341.89
# Other Income ...
# Value            NaN  Attribute
# Other Income    1034.46
# Other Income...
# Value         168.28  Attribute
# Other Income    0.86
# Other Income   ...
# Value          15.99                                             154.15
# Value        3969.98                                            1197.36
# ...              ...                                                ...
# Value       23354.30                                             311.30
# Value          29.59                                             168.45
# Value        1007.70                                            2265.70
# Value          70.24  Attribute
# Other Income    79.72
# Other Income  ...
# Value         129.90  Attribute
# Other Income    186.60
# Other Income ...
#
# Key    Net Cash Used In Investing Activities Inventories Current Assets  \
# Value                               -4637.30     1624.20        7840.44
# Value                               -4319.50                        NaN
# Value                               -1329.78     1031.05        2258.55
# Value                                -147.71      648.85        1088.05
# Value                              -16860.09     6918.05       31583.04
# ...                                      ...         ...            ...
# Value                               -5413.60       16.30       13047.50
# Value                                 -81.60     1591.97        5430.95
# Value                               -8406.50      118.80       25998.40
# Value                                -201.58     7307.89       10587.81
# Value                                1171.20     3413.30        8824.00
#
# Key   Current Liabilities  Working Capital  Minority Interest Balance Sheet  \
# Value             5641.01          2199.43                             3.48
# Value                 NaN              NaN                              NaN
# Value              544.02          1714.53                             0.72
# Value             1206.02          -117.97                              NaN
# Value            39073.46         -7490.42                          4839.04
# ...                   ...              ...                              ...
# Value            47726.80        -34679.30                             0.00
# Value             4024.72          1406.23                            41.65
# Value            17893.20          8105.20                            58.90
# Value             2651.67          7936.14                             0.00
# Value             4367.50          4456.50                          2172.50
#
# Key    Other Income Balance Sheet
# Value                      341.89
# Value                     1034.46
# Value                        0.86
# Value                           1
# Value                           1
# ...                           ...
# Value                           3
# Value                           1
# Value                           2
# Value                       79.72
# Value                      186.60
#
# [179 rows x 22 columns]

# %%
fin['Minority Interest'].apply(extract_first_integer)
# Out:
# '341.89'

# %%
# for i in range(fin.shape[0]):
    
#     print(i, fin["Minority Interest"][i][0])

# %%
# stock_list, financial_fin = cleaning_func(bs, pl, cfs, incs)
# metric_creation(bs,cfs, incs,pl)

# %%
fin.Stock.nunique()
# Out:
# 179

# %%
# gen_stock[gen_stock["Value"] == "TTM EPS See historical trend"]
# fin = metric_creation(bs, cfs, incs, pl)

# gen_fin = pd.DataFrame()

# %%
# st = pd.DataFrame()
# gen_stock_selected = gen_stock[gen_stock["Stock"] == i]
# # ["Stock","Dividend Yield", "Mkt Cap (Rs. Cr.)","TTM EPS See historical trend","Open"]
# st["Stock"] = i
# st["Dividend Yield"] = gen_stock_selected[gen_stock_selected["Value"] == "Dividend Yield"]["Num"].values
# st["Mkt Cap (Rs. Cr.)"] = gen_stock_selected[gen_stock_selected["Value"] == "Mkt Cap (Rs. Cr.)"]["Num"].values
# st["TTM EPS See historical trend"] = gen_stock_selected[gen_stock_selected["Value"] == "TTM EPS See historical trend"]["Num"].values
# st["Open"] = gen_stock_selected[gen_stock_selected["Value"] == "Open"]["Num"].values[0]

# st

# %%
# gen_stock_selected[gen_stock_selected["Value"] == "Open"]["Num"].values[0]

# %%
# gen_stock[gen_stock["Value"] == "Open"]

# %%
# gen_stock_selected_transpose

# %%
gen_stock
# Out:
#       Unnamed: 0           Value       Num           Stock
# 0              0            Open    4213.3        abbindia
# 1              1  Previous Close    4192.7        abbindia
# 2              2          Volume  158952.0        abbindia
# 3              3    Value (Lacs)   6652.78        abbindia
# 4              4         i  VWAP   4194.58        abbindia
# ...          ...             ...       ...             ...
# 5510           3     Value(lacs)       - -  shriramfinance
# 5511           0            High       - -  shriramfinance
# 5512           1             Low       - -  shriramfinance
# 5513           2             ATP       - -  shriramfinance
# 5514           3            Spot       - -  shriramfinance
#
# [5515 rows x 4 columns]

# %%
gen_fin = pd.DataFrame()

for i in gen_stock["Stock"].unique():

    tab = gen_stock_flat(gen_stock, i)
#     gen_fin[i] = tab
    gen_fin = pd.concat([gen_fin, tab], ignore_index=True)

# %%
gen_fin
# Out:
#     Dividend Yield Mkt Cap (Rs. Cr.) TTM EPS See historical trend     Open  \
# 0             0.13             88692          0.00  (+27.02% YoY)   4213.3
# 1             0.45             38284         38.74  (-46.24% YoY)   1998.0
# 2             0.14             47828          0.00  (+22.14% YoY)    718.9
# 3             0.52             17545         13.24  (-63.95% YoY)   479.35
# 4             1.45             47663          0.00  (+27.88% YoY)  22800.0
# ..             ...               ...                          ...      ...
# 179           0.49             28545          4.70  (-68.35% YoY)   856.15
# 180           0.24            219919          22.32  (+5.94% YoY)    409.0
# 181           0.00             24940                        -1.17    262.0
# 182           1.00             60717         24.98  (-42.11% YoY)    603.3
# 183           1.84             71282        156.09  (+20.03% YoY)  1907.05
#
#                            Stock
# 0                       abbindia
# 1                            acc
# 2             ausmallfinancebank
# 3                aartiindustries
# 4                    abbottindia
# ..                           ...
# 179                       voltas
# 180                        wipro
# 181  zeeentertainmententerprises
# 182            zyduslifesciences
# 183               shriramfinance
#
# [184 rows x 5 columns]

# %%
# [df.reset_index(drop=True).assign(key=key) for key, df in gen_fin.items()][7]

# %%
# pd.concat([df.reset_index(drop=True).assign(key=key) for key, df in gen_fin.items()], ignore_index=True)

# %%
#     print(tab)
#     gen_fin = gen_fin + tab

#     gen_fin = pd.concat([gen_fin, tab], ignore_index=True)

# %%
gen_fin

# %%
# gen_fin = {}
# for i in gen_stock.Stock.unique():
#     tab = gen_stock_flat(gen_stock, i)
# #     tab.reset_index(inplace=True, drop=True)

#     gen_fin[i] = tab
#     print(i)
#     gen_fin.append(tab)

#     gen_fin = pd.concat([gen_fin, tab], ignore_index=True)

# %%
gen_fin["abbindia"]
# Out:
# Value     Stock Dividend Yield Mkt Cap (Rs. Cr.) TTM EPS See historical trend  \
# 0      abbindia           0.13             88692          0.00  (+27.02% YoY)
#
# Value    Open Open
# 0      4213.3  - -

# %%
gen_fin["acc"]
# Out:
# Value Stock Dividend Yield Mkt Cap (Rs. Cr.) TTM EPS See historical trend  \
# 0       acc           0.45             38284         38.74  (-46.24% YoY)
#
# Value    Open Open
# 0      1998.0  - -

# %%
# gen_fin.items()

# %%
# pd.concat([df.assign(key=key) for key, df in gen_fin.items()])
# pd.concat([df.assign(key=key) for key, df in gen_fin.items()], ignore_index=True)

# %%
pd.DataFrame(gen_fin, index=['i',])

# %%
merged = gen_fin.merge(fin, on=["Stock"])

# %%
fin.Stock.nunique()
# Out:
# 155

# %%
def gen_stock_metric(gen_stock, bs, cfs, incs, pl):

    gen_stock[gen_stock["Value"] == "TTM EPS See historical trend"]
    fin = metric_creation(bs, cfs, incs, pl)
    gen_fin = pd.DataFrame()

    for i in gen_stock.Stock.unique():
        tab = gen_stock_flat(gen_stock, i)
        gen_fin = pd.concat([gen_fin, tab], ignore_index=True)

    merged = gen_fin.merge(fin, on=["Stock"])

    merged["Current_Ratio"] = merged["Current Assets"] / merged["Current Liabilities"]
    merged["Inventories"] = pd.to_numeric(merged["Inventories"])
    merged["Quick_Ratio"] = (merged["Current Assets"] - merged["Inventories"]) / merged["Current Liabilities"]
    merged["BookToMkt"] = merged["Total Shareholders Funds"].astype("float") / merged["Mkt Cap (Rs. Cr.)"].astype(
        "float")
    merged["Net Debt"] = fin["Long Term Borrowings"].astype("float") - fin["Cash And Cash Equivalents"].astype("float")
    merged["TEV"] = merged["Mkt Cap (Rs. Cr.)"].astype("float") + merged["Net Debt"].astype("float") + merged[
        "Minority Interest Balance Sheet"].astype("float")

    merged["EarningYield"] = merged["EBIT"].astype('float') / merged["TEV"].astype('float')


    return merged

# %%
fin = metric_creation(bs, cfs, incs, pl)
# Out:
# abbindia
# acc
# ausmallfinancebank
# aartiindustries
# abbottindia
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# adanienterprises
# adaniportsspecialeconomiczone
# adityabirlacapital
# adityabirlafashionretail
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# alkemlaboratories
# ambujacements
# apollohospitalsenterprises
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# apollotyres
# ashokleyland
# asianpaints
# astrallimited
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# atul
# aurobindopharma
# axisbank
# bajajauto
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# bajajfinance
# bajajfinserv
# balkrishnaindustries
# balrampurchinimills
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# bandhanbank
# bankbaroda
# bataindia
# bergerpaintsindia
# bharatelectronics
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# bharatforge
# bharatheavyelectricals
# bharatpetroleumcorporation
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# bhartiairtel
# biocon
# birlasoft
# bosch
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# britanniaindustries
# canfinhomes
# canarabank
# chambalfertiliserschemicals
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# cholamandalaminvestmentfinancecompany
# cipla
# cityunionbank
# coalindia
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# coforgelimited
# colgatepalmoliveindia
# containercorporationindia
# coromandelinternational
# cromptongreavesconsumerelectrical
# cumminsindia
# dlf
# daburindia
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# dalmiabharat
# deepaknitrite
# deltacorp
# divislaboratories
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# dixontechnologies
# drlalpathlabs
# drreddyslaboratories
# eichermotors
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# escortskubota
# exideindustries
# federalbank
# gailindia
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# gmrairportsinfrastructure
# glenmarkpharma
# godrejconsumerproducts
# godrejproperties
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# granulesindia
# grasimindustries
# gujaratgas
# gujaratnarmadavalleyfertchem
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# hcltechnologies
# hdfcassetmanagementcompany
# hdfcbank
# hdfclifeinsurancecompany
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# havellsindia
# heromotocorp
# hindalcoindustries
# hindustanaeronauticsltd
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# hindustancopper
# hindustanpetroleumcorporation
# hindustanunilever
# icicibank
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# icicilombardgeneralinsurancecompany
# iciciprudentiallifeinsurancecompany
# idfcfirstbank
# idfc
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# itc
# indiacements
# indiabullshousingfinance
# indiamartintermesh
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# indianenergyexchange
# indianhotelscompany
# indianoilcorporation
# irctc-indianrailwaycateringtourismcorp
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# indraprasthagas
# industowers
# indusindbank
# infoedgeindia
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# infosys
# interglobeaviation
# ipcalaboratories
# jkcement
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# jswsteel
# jindalsteelpower
# jubilantfoodworks
# kotakmahindrabank
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# ltfinanceholdings
# lttechnologyservices
# lichousingfinance
# ltimindtree
# larsentoubro
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# lauruslabs
# lupin
# mrf
# mahanagargas
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# rec
# relianceindustries
# sbicardspaymentservices
# sbilifeinsurancecompany
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# srf
# samvardhanamothersoninternational
# shreecements
# shriramfinance
# siemens
# statebankindia
# steelauthorityindia
# sunpharmaceuticalindustries
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# suntvnetwork
# syngeneinternational
# tvsmotorcompany
# tatachemicals
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# tatacommunications
# tataconsultancyservices
# tataconsumerproducts
# tatamotors
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# thetatapowercompany
# tatasteel
# techmahindra
# theramcocements
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# titancompany
# torrentpharmaceuticals
# trent
# upl
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# ultratechcement
# unitedbreweries
# unitedspirits
# vedanta
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# vodafoneidealimited
# voltas
# wipro
# zeeentertainmententerprises
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\347445355.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   financial_fin_st_T_selected["Year"] = year
# zyduslifesciences
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\1482913630.py:40: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fin['Minority Interest Balance Sheet'][i] = fin['Minority Interest'][i][0]
# C:\Users\Asehgal\AppData\Local\Temp\ipykernel_22708\1482913630.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fin['Other Income PnL'][i] = fin['Other Income'][i].values[0]

# %%
fin.Stock.nunique()
# Out:
# 167

# %% [raw]
# merged = gen_stock_metric(gen_stock, bs, cfs, incs, pl)

# %%
merged.Stock.nunique()
# Out:
# 167

# %%
# fin = metric_creation(bs, cfs, incs, pl)

# %%
merged.Stock.nunique()
# Out:
# 155

# %% [raw]
# ### To check
# 1. Why all stocks not captured
# 2. why dfs not merged correctly
# 3. why minority interest and other income have "attribute" in it
# 4. cross check if the values are shown correct in the dataframe

# %% [raw]
# 5. add call put ratio of stocks

# %% [raw]
# 6. Add sectors of stock
# 7. Comparison with sector leader, sector average
# 8. Think of stop loss logics
# 9. Add mid cap, small cap etc fiters
